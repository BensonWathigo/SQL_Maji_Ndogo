# %% [markdown]
# # Part 3 Maji Ndogo project: From analysis to action:

# %% [markdown]
# ##
# The goals of this part of the project are
#
# 1. Integrating the auditors report data into our database: an independent auditor was approached to authenticate the water sources, pollution levels and the residents comments on the surveyors conduct
#
#  2.Generating an ERD from the database
#
# 3.Linking records: joining our employee data to the auditor report
#
# 4. Seeking the truth: bulding a complex query to investigate employee corruption:

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:L0xbysmrben%23@localhost:3306/md_water_services

# %% [markdown]
# ## Importing the Auditor's Report
#
# Now that we have a proper representation of the relationships in our database, we can proceed to import the data from the auditor's report which is in a .csv format. To do this, we need to follow the steps below
#
# 1. Create an empty auditor_report table in the md_water_services database. To do this, we run the following in MySQL Workbench:
#
#     ```sql
#     DROP TABLE IF EXISTS `auditor_report`;
#
#     CREATE TABLE `auditor_report` (
#         `location_id` VARCHAR(32),
#         `type_of_water_source` VARCHAR(64),
#         `true_water_source_score` INT DEFAULT NULL,
#         `statements` VARCHAR(255)
#     );
# 2. Import the data sent by the auditor in .csv format on MySQL Workbench. Remember to use an existing table since we've already created an empty table from the first step.from the first step.

# %% [markdown]
# # Auditor's Report Integration
#
# After we've imported the auditor's report into SQL database, at first glance, we can see that it has 1620 records alluding to all revisited sites by the auditor. The report also has the following attributes:
# - `location_id` for the revisited locations.
# - `type_of_water_source` that was visited by the auditor.
# - `true_water_source_score` assigned by the auditor as a measure of water quality.
# - `statements` captured while the auditor investigated each site by speaking to locals at the sites.
#
# Based on the auditors report, we can perform a comparative analysis against the surveyors rater_quality` tables.55)
# );

# %% [markdown]
# ## Questions to Answer
#
# Now that we have all our data in one place, let's try and answer the following questions:
#
# 1. Is there a difference in scores between the auditor's report and the data provided by the surveyors?
# 2. If a difference exists, is there a pattern we can identify?AR(255)
#     );

# %% [markdown]
# ## Investigating Differences in Auditor & Surveyor Scores
#
# To investigate if there are differences between auditor and surveyor water quality scores, we will have to perform some joins. Consider the following:
# - The `auditor_report` table in our database has a `location_id` attribute but the `water_quality` table only has `record_id` attribute which considers with a similar attribute in the `visits` table.
# - The `visits` table has both `location_id` and `record_id` attributes hence it is the perfect table to make the join and link the `auditor_report` and `water_quality` tables.

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 13 rows affected.
# [('auditor_report',),
#  ('combined_anallysis_table',),
#  ('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('incorrect_records',),
#  ('incorrect_tables',),
#  ('location',),
#  ('project_progress',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',)]

# %% [markdown]
# to verify the authenticity of the database, an audit was commisioned and the finding recorded in the auditor_report table. The auditors report records verified type of water source with its verified water source score as well as its location id. the auditor also included a column on remarks of the residents about the conduct of the surveyors.

# %%
# %%sql
# SELECT * FROM auditor_report
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('SoRu34980', 'well', 1, "Residents admired the official's commitment to enhancing urban life, praising their cooperative and inclusive approach."),
#  ('AkRu08112', 'well', 3, "Villagers spoke highly of the official's dedication and genuine interest in their lives, fostering a sense of belonging and appreciation."),
#  ('AkLu02044', 'river', 0, "Villagers were touched by the official's interactions, noting their humility, strong work ethic, and respectful attitude."),
#  ('AkHa00421', 'well', 3, "Villagers were moved by the official's visit, praising their hard work, humility, and the profound sense of connection they fostered."),
#  ('SoRu35221', 'river', 0, "A photographer's lens captures the queue, though his own struggle for water is a hidden part of the story."),
#  ('HaAm16170', 'well', 1, 'With an open heart, the official created an atmosphere of unity and familial camaraderie among the villagers.'),
#  ('AkRu04812', 'well', 3, "The official's presence left an indelible mark, reflecting their humility, dedication, and the genuine connections they nurtured."),
#  ('AkRu08304', 'well', 3, "The official's interactions resonated deeply with the villagers, leaving a lasting impression of respect and camaraderie."),
#  ('AkRu05107', 'well', 2, "Villagers spoke highly of the official's dedication and genuine interest in their lives, fostering a sense of belonging and appreciation."),
#  ('AkRu05215', 'well', 3, "Villagers admired the official's visit for its respectful interactions, hard work, and genuine concern.")]

# %% [markdown]
# We confirm that the auditor's report contains a total of **1620** records shown by the output from running the cell above. These are unique locations where the auditor revisited and reassigned water quality scores. With that out of the way, there are a couple of steps we need to take to build the right SQL query to get the information we need from the various tables. Let's start with the following:
#
# 1. Grab the `location_id` and `true_water_source_score` attributes from the `auditor_report` entity.
# 2. **JOIN** the `visits` entity to the auditor_report on the shared `location_id` attribute to get access to the `record_id` attribute.
# 3. **JOIN** the `water_quality` entity on the `record_id` attribute to retrieve the corresponding `subjective_quality_scores` attribute in the `water_quality` entity.
# 4. Clean the Resulting table by removing unnecessary redundant columns and renaming the score columns as `surveyor_score` and `auditor_score` respectively
# 5. Check if the `surveyor_score` and `auditor_score` are different using a `WHERE` clause in the query

# %%
# %%sql
# SELECT
#     a.location_id AS auditor_location,
#     a.true_water_source_score AS auditor_score,
#     q.subjective_quality_score AS surveyor_score,
#     v.record_id
# FROM
#     auditor_report AS a
# JOIN
#     visits AS v
#     ON a.location_id = v.location_id
# JOIN
#     water_quality AS q
#     ON v.record_id = q.record_id
# WHERE
#     a.true_water_source_score = q.subjective_quality_score;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2505 rows affected.
# [('SoRu34980', 1, 1, 5185),
#  ('AkRu08112', 3, 3, 59367),
#  ('AkLu02044', 0, 0, 37379),
#  ('AkHa00421', 3, 3, 51627),
#  ('SoRu35221', 0, 0, 28758),
#  ('HaAm16170', 1, 1, 31048),
#  ('AkRu04812', 3, 3, 1513),
#  ('AkRu08304', 3, 3, 1218),
#  ('AkRu05107', 2, 2, 8322),
#  ('HaDe16541', 2, 2, 13070),
#  ('KiRu30351', 9, 9, 54220),
#  ('AmAm09813', 4, 4, 191),
#  ('SoRu37005', 0, 0, 51172),
#  ('KiRu26067', 3, 3, 21010),
#  ('KiRu26067', 3, 3, 21098),
#  ('KiRu26067', 3, 3, 21162),
#  ('KiRu26067', 3, 3, 21254),
#  ('KiRu26067', 3, 3, 21281),
#  ('KiRu26067', 3, 3, 21315),
#  ('KiRu26067', 3, 3, 21403),
#  ('KiRu26067', 3, 3, 21476),
#  ('SoRu37100', 0, 0, 40276),
#  ('AmDa11611', 1, 1, 38071),
#  ('AkRu07801', 3, 3, 25278),
#  ('AkRu07801', 3, 3, 25371),
#  ('AkRu07801', 3, 3, 25405),
#  ('AkRu07801', 3, 3, 25432),
#  ('AkRu07801', 3, 3, 25461),
#  ('AkRu07801', 3, 3, 25520),
#  ('AkRu07801', 3, 3, 25667),
#  ('AkRu07801', 3, 3, 25691),
#  ('KiZu31015', 3, 3, 47319),
#  ('KiIs24026', 2, 2, 2942),
#  ('AkRu08480', 2, 2, 47118),
#  ('AmBe11043', 3, 3, 53502),
#  ('AmBe11043', 3, 3, 53545),
#  ('AmBe11043', 3, 3, 53616),
#  ('AmBe11043', 3, 3, 53737),
#  ('AmBe11043', 3, 3, 53795),
#  ('AmBe11043', 3, 3, 53818),
#  ('AmBe11043', 3, 3, 53916),
#  ('AmBe11043', 3, 3, 53939),
#  ('AmRu13718', 9, 9, 31092),
#  ('AmRu15209', 3, 3, 42546),
#  ('AmRu15209', 3, 3, 42604),
#  ('AmRu15209', 3, 3, 42632),
#  ('AmRu15209', 3, 3, 42711),
#  ('AmRu15209', 3, 3, 42742),
#  ('AmRu15209', 3, 3, 42834),
#  ('AmRu15209', 3, 3, 42918),
#  ('AmRu15209', 3, 3, 43057),
#  ('SoRu37428', 3, 3, 25748),
#  ('SoRu37428', 3, 3, 25798),
#  ('SoRu37428', 3, 3, 25854),
#  ('SoRu37428', 3, 3, 25860),
#  ('SoRu37428', 3, 3, 25888),
#  ('SoRu37428', 3, 3, 25988),
#  ('SoRu37428', 3, 3, 26070),
#  ('SoRu37428', 3, 3, 26199),
#  ('SoRu34787', 2, 2, 30989),
#  ('AkRu03204', 3, 3, 36239),
#  ('SoMa34137', 3, 3, 4657),
#  ('SoRu38874', 3, 3, 17601),
#  ('SoRu38874', 3, 3, 17627),
#  ('SoRu38874', 3, 3, 17650),
#  ('SoRu38874', 3, 3, 17661),
#  ('SoRu38874', 3, 3, 17805),
#  ('SoRu38874', 3, 3, 17810),
#  ('SoRu38874', 3, 3, 17897),
#  ('SoRu38874', 3, 3, 17987),
#  ('KiMr24320', 2, 2, 9219),
#  ('AkRu06460', 2, 2, 42913),
#  ('KiRu28673', 1, 1, 57339),
#  ('AkHa00193', 9, 9, 25090),
#  ('AmAs10732', 0, 0, 53977),
#  ('KiRu27585', 3, 3, 2193),
#  ('AkRu03541', 2, 2, 23766),
#  ('AkRu04448', 3, 3, 55253),
#  ('HaRu20155', 0, 0, 56131),
#  ('AmAm09990', 5, 5, 3820),
#  ('AmAm09990', 5, 5, 3830),
#  ('AmAm09990', 5, 5, 3923),
#  ('AmAm09990', 5, 5, 4034),
#  ('AmAm09990', 5, 5, 4072),
#  ('AmAm09990', 5, 5, 4150),
#  ('AmAm09990', 5, 5, 4176),
#  ('AmAm09990', 5, 5, 4263),
#  ('KiZu31024', 0, 0, 53881),
#  ('SoIl32392', 3, 3, 2825),
#  ('SoIl32392', 3, 3, 2902),
#  ('SoIl32392', 3, 3, 2973),
#  ('SoIl32392', 3, 3, 3118),
#  ('SoIl32392', 3, 3, 3181),
#  ('SoIl32392', 3, 3, 3201),
#  ('SoIl32392', 3, 3, 3216),
#  ('SoIl32392', 3, 3, 3232),
#  ('SoRu38699', 3, 3, 13821),
#  ('KiAm22079', 9, 9, 50732),
#  ('KiRu26316', 3, 3, 27240),
#  ('KiRu26316', 3, 3, 27307),
#  ('KiRu26316', 3, 3, 27418),
#  ('KiRu26316', 3, 3, 27482),
#  ('KiRu26316', 3, 3, 27569),
#  ('KiRu26316', 3, 3, 27645),
#  ('KiRu26316', 3, 3, 27670),
#  ('KiRu26316', 3, 3, 27769),
#  ('AkKi01456', 9, 9, 57050),
#  ('AkRu08152', 2, 2, 43992),
#  ('KiRu27444', 7, 7, 18928),
#  ('HaRu20693', 1, 1, 55091),
#  ('AkRu04981', 3, 3, 8803),
#  ('KiRu28580', 1, 1, 14177),
#  ('KiRu30008', 1, 1, 25914),
#  ('SoMa34631', 2, 2, 55851),
#  ('SoKo33227', 1, 1, 31236),
#  ('AmRu14465', 3, 3, 23398),
#  ('AmRu14465', 3, 3, 23526),
#  ('AmRu14465', 3, 3, 23541),
#  ('AmRu14465', 3, 3, 23577),
#  ('AmRu14465', 3, 3, 23666),
#  ('AmRu14465', 3, 3, 23748),
#  ('AmRu14465', 3, 3, 23794),
#  ('AmRu14465', 3, 3, 23848),
#  ('AkHa00008', 3, 3, 57788),
#  ('HaRu19826', 9, 9, 55626),
#  ('AmDa11947', 1, 1, 23857),
#  ('AmPw12680', 3, 3, 45472),
#  ('AmPw12680', 3, 3, 45588),
#  ('AmPw12680', 3, 3, 45653),
#  ('AmPw12680', 3, 3, 45752),
#  ('AmPw12680', 3, 3, 45778),
#  ('AmPw12680', 3, 3, 45798),
#  ('AmPw12680', 3, 3, 45809),
#  ('AmPw12680', 3, 3, 45878),
#  ('HaDe16514', 1, 1, 42469),
#  ('KiMr24591', 0, 0, 44892),
#  ('KiIs24014', 1, 1, 36889),
#  ('AkRu07523', 3, 3, 22404),
#  ('AkRu04753', 9, 9, 55958),
#  ('SoRu36774', 2, 2, 35173),
#  ('SoRu36239', 2, 2, 43524),
#  ('KiRu27776', 3, 3, 23770),
#  ('KiRu27776', 3, 3, 23881),
#  ('KiRu27776', 3, 3, 23970),
#  ('KiRu27776', 3, 3, 24020),
#  ('KiRu27776', 3, 3, 24065),
#  ('KiRu27776', 3, 3, 24089),
#  ('KiRu27776', 3, 3, 24159),
#  ('KiRu27776', 3, 3, 24268),
#  ('AkRu03164', 3, 3, 42866),
#  ('AkRu05809', 2, 2, 8004),
#  ('KiRu28632', 5, 5, 32143),
#  ('KiRu28632', 5, 5, 32283),
#  ('KiRu28632', 5, 5, 32304),
#  ('KiRu28632', 5, 5, 32342),
#  ('KiRu28632', 5, 5, 32431),
#  ('KiRu28632', 5, 5, 32486),
#  ('KiRu28632', 5, 5, 32577),
#  ('KiRu28632', 5, 5, 32667),
#  ('KiRu30389', 4, 4, 17755),
#  ('AkKi01375', 3, 3, 40201),
#  ('SoRu37530', 0, 0, 55624),
#  ('AmBe10959', 4, 4, 23719),
#  ('HaRu19828', 2, 2, 25621),
#  ('SoIl32999', 2, 2, 32992),
#  ('HaRu18571', 2, 2, 56000),
#  ('AkRu08666', 6, 6, 56276),
#  ('AkRu03306', 7, 7, 29135),
#  ('AkRu08936', 3, 3, 132),
#  ('HaSe21341', 3, 3, 59324),
#  ('SoRu35327', 1, 1, 59821),
#  ('AmRu14903', 9, 9, 54574),
#  ('AmAb09101', 6, 6, 10635),
#  ('KiAm22276', 0, 0, 15269),
#  ('HaRu20617', 1, 1, 18740),
#  ('HaRu18217', 1, 1, 58386),
#  ('KiRu29806', 9, 9, 35488),
#  ('KiRu28057', 1, 1, 25822),
#  ('AkRu06170', 3, 3, 16253),
#  ('AkRu03380', 3, 3, 45718),
#  ('KiRu26678', 2, 2, 17842),
#  ('AmBe10942', 9, 9, 23182),
#  ('KiIs23730', 3, 3, 59182),
#  ('KiIs23730', 3, 3, 59319),
#  ('KiIs23730', 3, 3, 59413),
#  ('KiIs23730', 3, 3, 59440),
#  ('KiIs23730', 3, 3, 59585),
#  ('KiIs23730', 3, 3, 59600),
#  ('KiIs23730', 3, 3, 59630),
#  ('KiIs23730', 3, 3, 59659),
#  ('KiHa23034', 3, 3, 39514),
#  ('KiRu28090', 6, 6, 493),
#  ('AmRu13729', 2, 2, 12421),
#  ('HaRu18016', 1, 1, 43421),
#  ('KiRu27440', 9, 9, 46897),
#  ('HaYa21606', 3, 3, 54414),
#  ('HaRu17207', 1, 1, 41291),
#  ('AmAm09735', 1, 1, 19578),
#  ('HaRu20534', 2, 2, 36976),
#  ('AmPw12770', 3, 3, 57820),
#  ('AkLu02096', 3, 3, 46932),
#  ('HaRu20434', 2, 2, 26351),
#  ('AkRu02688', 0, 0, 28038),
#  ('AmBe11285', 9, 9, 30594),
#  ('AmRu13720', 3, 3, 57704),
#  ('AmRu13720', 3, 3, 57829),
#  ('AmRu13720', 3, 3, 57844),
#  ('AmRu13720', 3, 3, 57849),
#  ('AmRu13720', 3, 3, 57870),
#  ('AmRu13720', 3, 3, 57968),
#  ('AmRu13720', 3, 3, 58108),
#  ('AmRu13720', 3, 3, 58163),
#  ('SoMa33819', 0, 0, 41990),
#  ('SoRu38119', 1, 1, 32719),
#  ('AmRu12983', 3, 3, 34259),
#  ('SoRu35906', 5, 5, 23263),
#  ('SoRu35906', 5, 5, 23333),
#  ('SoRu35906', 5, 5, 23420),
#  ('SoRu35906', 5, 5, 23532),
#  ('SoRu35906', 5, 5, 23546),
#  ('SoRu35906', 5, 5, 23587),
#  ('SoRu35906', 5, 5, 23677),
#  ('SoRu35906', 5, 5, 23693),
#  ('KiRu27742', 3, 3, 20199),
#  ('SoRu35991', 3, 3, 49145),
#  ('KiRu28083', 4, 4, 28642),
#  ('AmRu15159', 9, 9, 3238),
#  ('HaYa21456', 2, 2, 31258),
#  ('HaRu18734', 2, 2, 9967),
#  ('SoRu35970', 3, 3, 49787),
#  ('AmAs10285', 3, 3, 35054),
#  ('AmAs10285', 3, 3, 35109),
#  ('AmAs10285', 3, 3, 35135),
#  ('AmAs10285', 3, 3, 35257),
#  ('AmAs10285', 3, 3, 35277),
#  ('AmAs10285', 3, 3, 35454),
#  ('AmAs10285', 3, 3, 35462),
#  ('AmAs10285', 3, 3, 35578),
#  ('KiZu31223', 3, 3, 45820),
#  ('KiZu31223', 3, 3, 45947),
#  ('KiZu31223', 3, 3, 46006),
#  ('KiZu31223', 3, 3, 46113),
#  ('KiZu31223', 3, 3, 46153),
#  ('KiZu31223', 3, 3, 46222),
#  ('KiZu31223', 3, 3, 46246),
#  ('KiZu31223', 3, 3, 46251),
#  ('SoRu38546', 9, 9, 31987),
#  ('AmPw12293', 6, 6, 43323),
#  ('SoRu39488', 3, 3, 778),
#  ('SoRu39488', 3, 3, 889),
#  ('SoRu39488', 3, 3, 902),
#  ('SoRu39488', 3, 3, 927),
#  ('SoRu39488', 3, 3, 984),
#  ('SoRu39488', 3, 3, 1043),
#  ('SoRu39488', 3, 3, 1178),
#  ('SoRu39488', 3, 3, 1199),
#  ('SoRu39408', 5, 5, 9997),
#  ('SoRu39408', 5, 5, 10080),
#  ('SoRu39408', 5, 5, 10156),
#  ('SoRu39408', 5, 5, 10194),
#  ('SoRu39408', 5, 5, 10197),
#  ('SoRu39408', 5, 5, 10298),
#  ('SoRu39408', 5, 5, 10444),
#  ('SoRu39408', 5, 5, 10496),
#  ('HaRu17750', 2, 2, 55863),
#  ('KiRu30604', 0, 0, 38650),
#  ('KiZu30905', 9, 9, 38879),
#  ('SoRu39374', 9, 9, 12919),
#  ('SoRu37406', 2, 2, 36882),
#  ('AkRu05212', 9, 9, 41421),
#  ('SoIl32294', 0, 0, 58139),
#  ('AmBe11313', 0, 0, 12271),
#  ('SoRu35426', 3, 3, 12319),
#  ('AkHa00073', 3, 3, 13554),
#  ('SoRu35899', 9, 9, 10054),
#  ('KiRu26664', 2, 2, 30561),
#  ('SoRu36580', 3, 3, 15465),
#  ('SoRu36580', 3, 3, 15591),
#  ('SoRu36580', 3, 3, 15594),
#  ('SoRu36580', 3, 3, 15682),
#  ('SoRu36580', 3, 3, 15764),
#  ('SoRu36580', 3, 3, 15815),
#  ('SoRu36580', 3, 3, 15846),
#  ('SoRu36580', 3, 3, 15996),
#  ('AkLu02432', 2, 2, 56526),
#  ('HaRu19287', 5, 5, 54666),
#  ('HaRu19287', 5, 5, 54686),
#  ('HaRu19287', 5, 5, 54700),
#  ('HaRu19287', 5, 5, 54724),
#  ('HaRu19287', 5, 5, 54884),
#  ('HaRu19287', 5, 5, 54897),
#  ('HaRu19287', 5, 5, 54983),
#  ('HaRu19287', 5, 5, 55053),
#  ('SoRu38915', 1, 1, 26133),
#  ('KiRu26032', 0, 0, 12342),
#  ('KiRu25619', 3, 3, 48832),
#  ('AkHa00172', 2, 2, 41191),
#  ('KiRu27927', 3, 3, 33105),
#  ('KiRu28045', 2, 2, 16862),
#  ('KiRu29614', 1, 1, 51573),
#  ('KiRu25484', 1, 1, 20447),
#  ('AkRu04989', 1, 1, 34369),
#  ('AkKi01455', 3, 3, 16750),
#  ('AkKi01455', 3, 3, 16781),
#  ('AkKi01455', 3, 3, 16787),
#  ('AkKi01455', 3, 3, 16887),
#  ('AkKi01455', 3, 3, 16967),
#  ('AkKi01455', 3, 3, 17025),
#  ('AkKi01455', 3, 3, 17124),
#  ('AkKi01455', 3, 3, 17139),
#  ('SoIl33047', 2, 2, 45984),
#  ('SoCh32025', 0, 0, 14252),
#  ('KiRu28089', 0, 0, 9134),
#  ('AkRu07622', 2, 2, 18841),
#  ('KiRu29909', 1, 1, 28639),
#  ('AmBe11266', 9, 9, 6032),
#  ('KiRu26934', 2, 2, 44733),
#  ('SoRu35691', 5, 5, 13341),
#  ('SoRu35691', 5, 5, 13440),
#  ('SoRu35691', 5, 5, 13482),
#  ('SoRu35691', 5, 5, 13504),
#  ('SoRu35691', 5, 5, 13549),
#  ('SoRu35691', 5, 5, 13591),
#  ('SoRu35691', 5, 5, 13742),
#  ('SoRu35691', 5, 5, 13810),
#  ('SoMa34148', 2, 2, 50300),
#  ('AmRu15860', 1, 1, 46070),
#  ('SoRu38125', 5, 5, 26141),
#  ('SoRu38125', 5, 5, 26252),
#  ('SoRu38125', 5, 5, 26300),
#  ('SoRu38125', 5, 5, 26322),
#  ('SoRu38125', 5, 5, 26358),
#  ('SoRu38125', 5, 5, 26410),
#  ('SoRu38125', 5, 5, 26502),
#  ('SoRu38125', 5, 5, 26634),
#  ('AkLu02637', 9, 9, 13812),
#  ('SoRu35824', 1, 1, 28362),
#  ('KiRu27806', 0, 0, 42076),
#  ('AkRu03182', 3, 3, 13651),
#  ('AkHa00088', 1, 1, 12774),
#  ('SoRu36828', 2, 2, 5668),
#  ('AkLu02438', 9, 9, 24429),
#  ('SoRu38250', 6, 6, 21140),
#  ('AkHa00613', 3, 3, 20924),
#  ('KiMr25005', 0, 0, 58102),
#  ('AkRu04428', 3, 3, 9203),
#  ('SoRu35103', 5, 5, 44051),
#  ('SoRu35103', 5, 5, 44145),
#  ('SoRu35103', 5, 5, 44178),
#  ('SoRu35103', 5, 5, 44237),
#  ('SoRu35103', 5, 5, 44338),
#  ('SoRu35103', 5, 5, 44370),
#  ('SoRu35103', 5, 5, 44394),
#  ('SoRu35103', 5, 5, 44522),
#  ('SoRu36975', 0, 0, 26255),
#  ('AkHa00662', 2, 2, 52082),
#  ('SoCh31985', 3, 3, 37231),
#  ('SoRu37129', 0, 0, 31642),
#  ('SoRu38416', 3, 3, 49607),
#  ('SoRu38416', 3, 3, 49625),
#  ('SoRu38416', 3, 3, 49798),
#  ('SoRu38416', 3, 3, 49817),
#  ('SoRu38416', 3, 3, 49850),
#  ('SoRu38416', 3, 3, 49869),
#  ('SoRu38416', 3, 3, 49977),
#  ('SoRu38416', 3, 3, 50037),
#  ('AkRu02670', 2, 2, 8346),
#  ('AkHa00487', 3, 3, 14442),
#  ('SoRu36186', 0, 0, 16286),
#  ('AkRu03649', 2, 2, 4101),
#  ('SoMa34044', 0, 0, 20902),
#  ('AmRu14531', 9, 9, 13172),
#  ('SoRu37317', 2, 2, 50347),
#  ('KiIs23613', 6, 6, 3093),
#  ('SoRu39288', 0, 0, 13409),
#  ('AkRu07820', 3, 3, 34009),
#  ('AkRu07774', 3, 3, 24774),
#  ('SoRu36385', 2, 2, 54896),
#  ('KiIs24054', 9, 9, 21978),
#  ('KiRu29129', 1, 1, 32520),
#  ('KiHa23042', 1, 1, 54900),
#  ('AkHa00459', 1, 1, 39863),
#  ('SoBa31659', 3, 3, 17354),
#  ('KiRu30394', 4, 4, 6624),
#  ('SoKo33111', 1, 1, 19195),
#  ('AkRu03429', 3, 3, 17142),
#  ('KiRu26860', 0, 0, 24912),
#  ('KiAm22303', 9, 9, 56325),
#  ('HaRu18493', 3, 3, 25264),
#  ('HaRu18608', 1, 1, 4779),
#  ('SoRu35964', 2, 2, 58643),
#  ('KiMr24872', 2, 2, 47577),
#  ('KiAm22458', 2, 2, 672),
#  ('AkRu05603', 3, 3, 54483),
#  ('HaRu20851', 9, 9, 56353),
#  ('KiRu25343', 1, 1, 41757),
#  ('SoRu36816', 3, 3, 57218),
#  ('HaRu20840', 3, 3, 43798),
#  ('HaRu20840', 3, 3, 43873),
#  ('HaRu20840', 3, 3, 43894),
#  ('HaRu20840', 3, 3, 43914),
#  ('HaRu20840', 3, 3, 44065),
#  ('HaRu20840', 3, 3, 44121),
#  ('HaRu20840', 3, 3, 44189),
#  ('HaRu20840', 3, 3, 44278),
#  ('SoRu38966', 5, 5, 3240),
#  ('SoRu37494', 9, 9, 17009),
#  ('HaRu19176', 1, 1, 25331),
#  ('AmBe11175', 3, 3, 22982),
#  ('AmBe11175', 3, 3, 23048),
#  ('AmBe11175', 3, 3, 23088),
#  ('AmBe11175', 3, 3, 23094),
#  ('AmBe11175', 3, 3, 23115),
#  ('AmBe11175', 3, 3, 23200),
#  ('AmBe11175', 3, 3, 23287),
#  ('AmBe11175', 3, 3, 23453),
#  ('HaDe16360', 1, 1, 19732),
#  ('AmBe11054', 9, 9, 8225),
#  ('AkRu08460', 2, 2, 59776),
#  ('SoKo33124', 3, 3, 2006),
#  ('SoKo33124', 3, 3, 2107),
#  ('SoKo33124', 3, 3, 2220),
#  ('SoKo33124', 3, 3, 2278),
#  ('SoKo33124', 3, 3, 2304),
#  ('SoKo33124', 3, 3, 2330),
#  ('SoKo33124', 3, 3, 2373),
#  ('SoKo33124', 3, 3, 2458),
#  ('AkKi01211', 3, 3, 16824),
#  ('SoIl32445', 2, 2, 25386),
#  ('AmRu13532', 9, 9, 39886),
#  ('SoRu36142', 1, 1, 7542),
#  ('AkRu05020', 3, 3, 4291),
#  ('HaRu18730', 1, 1, 34773),
#  ('KiRu25527', 2, 2, 30088),
#  ('AkRu05442', 3, 3, 59724),
#  ('AkRu05207', 3, 3, 53713),
#  ('AkRu05207', 3, 3, 53800),
#  ('AkRu05207', 3, 3, 53824),
#  ('AkRu05207', 3, 3, 53914),
#  ('AkRu05207', 3, 3, 53928),
#  ('AkRu05207', 3, 3, 54036),
#  ('AkRu05207', 3, 3, 54157),
#  ('AkRu05207', 3, 3, 54160),
#  ('AmAm09844', 9, 9, 39550),
#  ('AkRu04217', 3, 3, 18145),
#  ('SoRu38733', 5, 5, 16689),
#  ('SoBa31655', 9, 9, 5710),
#  ('SoRu37392', 4, 4, 17821),
#  ('SoRu37392', 4, 4, 17894),
#  ('SoRu37392', 4, 4, 18045),
#  ('SoRu37392', 4, 4, 18088),
#  ('SoRu37392', 4, 4, 18116),
#  ('SoRu37392', 4, 4, 18215),
#  ('SoRu37392', 4, 4, 18263),
#  ('SoRu37392', 4, 4, 18383),
#  ('AkKi01238', 3, 3, 15839),
#  ('AmRu14527', 3, 3, 36952),
#  ('KiRu26502', 3, 3, 9396),
#  ('AkRu06339', 0, 0, 28338),
#  ('SoRu37920', 0, 0, 42676),
#  ('AkRu02682', 2, 2, 26484),
#  ('AmBe10969', 3, 3, 39852),
#  ('AmBe10969', 3, 3, 39963),
#  ('AmBe10969', 3, 3, 40094),
#  ('AmBe10969', 3, 3, 40134),
#  ('AmBe10969', 3, 3, 40214),
#  ('AmBe10969', 3, 3, 40307),
#  ('AmBe10969', 3, 3, 40313),
#  ('AmBe10969', 3, 3, 40414),
#  ('AkRu08755', 3, 3, 19813),
#  ('KiRu30051', 2, 2, 13174),
#  ('HaRu19054', 2, 2, 314),
#  ('HaRu17182', 1, 1, 26851),
#  ('AmBe11275', 3, 3, 26263),
#  ('AmBe11275', 3, 3, 26302),
#  ('AmBe11275', 3, 3, 26312),
#  ('AmBe11275', 3, 3, 26386),
#  ('AmBe11275', 3, 3, 26491),
#  ('AmBe11275', 3, 3, 26575),
#  ('AmBe11275', 3, 3, 26670),
#  ('AmBe11275', 3, 3, 26698),
#  ('HaRu19036', 2, 2, 52668),
#  ('KiMr24348', 2, 2, 40090),
#  ('AmPw12550', 9, 9, 28247),
#  ('HaRu20299', 2, 2, 43586),
#  ('KiRu29119', 1, 1, 25652),
#  ('AkRu03116', 3, 3, 32365),
#  ('SoRu35393', 1, 1, 23001),
#  ('AkLu02173', 1, 1, 27091),
#  ('AkRu08283', 3, 3, 45092),
#  ('KiRu28782', 3, 3, 58809),
#  ('KiRu28782', 3, 3, 58859),
#  ('KiRu28782', 3, 3, 58968),
#  ('KiRu28782', 3, 3, 59030),
#  ('KiRu28782', 3, 3, 59062),
#  ('KiRu28782', 3, 3, 59120),
#  ('KiRu28782', 3, 3, 59155),
#  ('KiRu28782', 3, 3, 59242),
#  ('AmAs10095', 3, 3, 46365),
#  ('KiRu29980', 1, 1, 5321),
#  ('KiRu25770', 3, 3, 37346),
#  ('AmRu15634', 3, 3, 24374),
#  ('AkRu07742', 2, 2, 3469),
#  ('KiRu28806', 1, 1, 26429),
#  ('AmAs10011', 9, 9, 44726),
#  ('KiMr25056', 1, 1, 36815),
#  ('HaDj16864', 1, 1, 25972),
#  ('HaRu18271', 1, 1, 14781),
#  ('HaAm16293', 3, 3, 55255),
#  ('KiRu27852', 2, 2, 30754),
#  ('AmAs10552', 9, 9, 16840),
#  ('HaAm16112', 2, 2, 15506),
#  ('KiZu30983', 3, 3, 5702),
#  ('HaYa21356', 2, 2, 36919),
#  ('AkRu03754', 3, 3, 6493),
#  ('SoMa34566', 2, 2, 39478),
#  ('AmRu15394', 1, 1, 15192),
#  ('HaRu19917', 9, 9, 53947),
#  ('SoRu35762', 1, 1, 47342),
#  ('AmAm09806', 9, 9, 41269),
#  ('AmAm09566', 9, 9, 37437),
#  ('KiRu27527', 2, 2, 30396),
#  ('SoRu36079', 0, 0, 41487),
#  ('AkLu02420', 2, 2, 46052),
#  ('SoRu38360', 0, 0, 30990),
#  ('KiIs23815', 2, 2, 15619),
#  ('AkLu01944', 3, 3, 29104),
#  ('SoBa31866', 1, 1, 15628),
#  ('AkRu05799', 3, 3, 53738),
#  ('KiRu26647', 1, 1, 31416),
#  ('AmRu14452', 3, 3, 3138),
#  ('AkRu03095', 3, 3, 59212),
#  ('AkRu03095', 3, 3, 59335),
#  ('AkRu03095', 3, 3, 59414),
#  ('AkRu03095', 3, 3, 59431),
#  ('AkRu03095', 3, 3, 59516),
#  ('AkRu03095', 3, 3, 59601),
#  ('AkRu03095', 3, 3, 59629),
#  ('AkRu03095', 3, 3, 59638),
#  ('SoRu37072', 1, 1, 34917),
#  ('SoBa31473', 2, 2, 18821),
#  ('SoRu35606', 3, 3, 3368),
#  ('SoRu35606', 3, 3, 3412),
#  ('SoRu35606', 3, 3, 3584),
#  ('SoRu35606', 3, 3, 3667),
#  ('SoRu35606', 3, 3, 3689),
#  ('SoRu35606', 3, 3, 3722),
#  ('SoRu35606', 3, 3, 3750),
#  ('SoRu35606', 3, 3, 3881),
#  ('KiRu28515', 2, 2, 48699),
#  ('KiMr24897', 9, 9, 17117),
#  ('AkRu03657', 2, 2, 56435),
#  ('AmAs10840', 9, 9, 9908),
#  ('SoRu37224', 2, 2, 30665),
#  ('HaRu20820', 2, 2, 43257),
#  ('KiIs23717', 3, 3, 18330),
#  ('HaRu18196', 1, 1, 51823),
#  ('KiRu28445', 1, 1, 9213),
#  ('AkRu04790', 9, 9, 2023),
#  ('AkLu01749', 3, 3, 37485),
#  ('SoRu35924', 2, 2, 36027),
#  ('KiRu27827', 2, 2, 48940),
#  ('AmRu13018', 5, 5, 34248),
#  ('AmRu13018', 5, 5, 34310),
#  ('AmRu13018', 5, 5, 34453),
#  ('AmRu13018', 5, 5, 34526),
#  ('AmRu13018', 5, 5, 34586),
#  ('AmRu13018', 5, 5, 34596),
#  ('AmRu13018', 5, 5, 34696),
#  ('AmRu13018', 5, 5, 34737),
#  ('SoRu36421', 0, 0, 20600),
#  ('KiRu28584', 1, 1, 52713),
#  ('KiRu29073', 2, 2, 28511),
#  ('AkHa00593', 2, 2, 29731),
#  ('AkKi01372', 3, 3, 49534),
#  ('AkKi01372', 3, 3, 49615),
#  ('AkKi01372', 3, 3, 49628),
#  ('AkKi01372', 3, 3, 49714),
#  ('AkKi01372', 3, 3, 49819),
#  ('AkKi01372', 3, 3, 49837),
#  ('AkKi01372', 3, 3, 49852),
#  ('AkKi01372', 3, 3, 49947),
#  ('AkLu02206', 3, 3, 4533),
#  ('AkRu08105', 2, 2, 25512),
#  ('AkRu04781', 2, 2, 56179),
#  ('KiRu27348', 1, 1, 56646),
#  ('AkRu07358', 3, 3, 50252),
#  ('SoRu35645', 3, 3, 17917),
#  ('HaDj16729', 1, 1, 44405),
#  ('AmAm09422', 9, 9, 28365),
#  ('KiRu28871', 9, 9, 46572),
#  ('SoKo33489', 2, 2, 21867),
#  ('KiIs24061', 2, 2, 42529),
#  ('SoRu36514', 6, 6, 33109),
#  ('SoRu38062', 0, 0, 55400),
#  ('AkRu04644', 3, 3, 51404),
#  ('AkRu04644', 3, 3, 51414),
#  ('AkRu04644', 3, 3, 51429),
#  ('AkRu04644', 3, 3, 51441),
#  ('AkRu04644', 3, 3, 51549),
#  ('AkRu04644', 3, 3, 51654),
#  ('AkRu04644', 3, 3, 51723),
#  ('AkRu04644', 3, 3, 51837),
#  ('AkRu07669', 2, 2, 6875),
#  ('KiMr24651', 3, 3, 54735),
#  ('SoRu35689', 0, 0, 44968),
#  ('KiZu31427', 9, 9, 22019),
#  ('KiMr24677', 1, 1, 57585),
#  ('HaRu17145', 1, 1, 58460),
#  ('SoKo33450', 2, 2, 52145),
#  ('AkRu06471', 2, 2, 22708),
#  ('AkRu03909', 6, 6, 48225),
#  ('SoRu38054', 0, 0, 36448),
#  ('KiZu30933', 0, 0, 10930),
#  ('AmRu15659', 3, 3, 21540),
#  ('AkRu04196', 1, 1, 6317),
#  ('HaRu17171', 3, 3, 56405),
#  ('KiZu31286', 5, 5, 58243),
#  ('KiZu31286', 5, 5, 58297),
#  ('KiZu31286', 5, 5, 58317),
#  ('KiZu31286', 5, 5, 58330),
#  ('KiZu31286', 5, 5, 58476),
#  ('KiZu31286', 5, 5, 58542),
#  ('KiZu31286', 5, 5, 58567),
#  ('KiZu31286', 5, 5, 58657),
#  ('KiRu27045', 9, 9, 25122),
#  ('AkRu07822', 2, 2, 38982),
#  ('SoRu38801', 5, 5, 30299),
#  ('SoRu38801', 5, 5, 30403),
#  ('SoRu38801', 5, 5, 30446),
#  ('SoRu38801', 5, 5, 30460),
#  ('SoRu38801', 5, 5, 30551),
#  ('SoRu38801', 5, 5, 30632),
#  ('SoRu38801', 5, 5, 30699),
#  ('SoRu38801', 5, 5, 30708),
#  ('AkRu05622', 2, 2, 37033),
#  ('AmRu13368', 3, 3, 59978),
#  ('KiRu29197', 2, 2, 3862),
#  ('KiHa22987', 2, 2, 51906),
#  ('AmAb09209', 0, 0, 2528),
#  ('SoRu35737', 1, 1, 12880),
#  ('HaRu20358', 1, 1, 32243),
#  ('SoRu38427', 0, 0, 27985),
#  ('SoRu39385', 2, 2, 26100),
#  ('KiAm22078', 3, 3, 14154),
#  ('HaRu18624', 2, 2, 571),
#  ('AkLu01620', 3, 3, 52324),
#  ('SoRu39442', 0, 0, 40218),
#  ('AmBe11161', 3, 3, 16638),
#  ('AmBe11161', 3, 3, 16757),
#  ('AmBe11161', 3, 3, 16763),
#  ('AmBe11161', 3, 3, 16810),
#  ('AmBe11161', 3, 3, 16830),
#  ('AmBe11161', 3, 3, 16982),
#  ('AmBe11161', 3, 3, 17054),
#  ('AmBe11161', 3, 3, 17120),
#  ('SoRu36982', 9, 9, 59694),
#  ('KiRu29202', 3, 3, 42496),
#  ('KiRu30289', 1, 1, 2112),
#  ('HaDj16691', 3, 3, 43418),
#  ('SoRu35904', 0, 0, 11602),
#  ('AkRu07627', 7, 7, 38984),
#  ('AkRu06941', 9, 9, 12025),
#  ('SoMa33925', 1, 1, 40620),
#  ('KiAm22052', 3, 3, 25833),
#  ('SoRu37929', 0, 0, 52815),
#  ('HaRu19467', 1, 1, 5732),
#  ('HaRu19164', 1, 1, 51451),
#  ('HaRu18836', 9, 9, 58049),
#  ('SoRu38150', 9, 9, 57491),
#  ('AmAm09853', 9, 9, 41120),
#  ('SoRu38947', 2, 2, 30376),
#  ('AmDa11683', 4, 4, 44700),
#  ('AmRu14207', 1, 1, 32491),
#  ('HaZa21638', 1, 1, 12606),
#  ('KiRu30052', 2, 2, 45489),
#  ('KiRu26263', 9, 9, 30172),
#  ('AmAb08975', 9, 9, 25976),
#  ('SoRu38924', 9, 9, 14792),
#  ('KiRu26698', 9, 9, 32554),
#  ('KiRu26909', 3, 3, 48857),
#  ('SoCh32037', 0, 0, 17084),
#  ('SoMa33775', 0, 0, 9767),
#  ('HaRu20481', 2, 2, 43336),
#  ('KiRu29745', 2, 2, 47317),
#  ('KiRu29612', 2, 2, 2867),
#  ('AmRu13754', 9, 9, 35709),
#  ('SoRu35482', 0, 0, 26148),
#  ('HaRu17297', 9, 9, 15430),
#  ('AkRu03158', 9, 9, 48151),
#  ('AkRu06069', 7, 7, 33352),
#  ('KiRu26010', 1, 1, 17435),
#  ('KiRu28019', 2, 2, 1195),
#  ('KiRu30518', 3, 3, 41822),
#  ('KiRu30518', 3, 3, 41957),
#  ('KiRu30518', 3, 3, 42024),
#  ('KiRu30518', 3, 3, 42041),
#  ('KiRu30518', 3, 3, 42143),
#  ('KiRu30518', 3, 3, 42167),
#  ('KiRu30518', 3, 3, 42265),
#  ('KiRu30518', 3, 3, 42318),
#  ('AkRu07026', 9, 9, 38714),
#  ('KiRu26412', 0, 0, 52839),
#  ('SoRu35634', 3, 3, 19157),
#  ('AkHa00746', 1, 1, 21385),
#  ('SoIl33036', 1, 1, 43651),
#  ('AkRu06836', 1, 1, 40555),
#  ('HaRu19773', 9, 9, 50727),
#  ('KiMr24471', 0, 0, 21173),
#  ('KiRu28420', 1, 1, 58254),
#  ('AkRu07739', 3, 3, 17453),
#  ('KiRu27252', 2, 2, 51552),
#  ('KiIs23560', 1, 1, 42504),
#  ('KiRu25537', 3, 3, 38191),
#  ('KiHa23219', 2, 2, 36052),
#  ('AkLu02008', 0, 0, 56663),
#  ('SoMa34421', 3, 3, 30111),
#  ('SoRu37753', 2, 2, 31486),
#  ('AmPw12576', 7, 7, 9330),
#  ('AmRu13851', 3, 3, 16435),
#  ('AmRu13851', 3, 3, 16506),
#  ('AmRu13851', 3, 3, 16597),
#  ('AmRu13851', 3, 3, 16748),
#  ('AmRu13851', 3, 3, 16770),
#  ('AmRu13851', 3, 3, 16807),
#  ('AmRu13851', 3, 3, 16812),
#  ('AmRu13851', 3, 3, 16987),
#  ('KiMr24804', 5, 5, 32189),
#  ('KiMr24804', 5, 5, 32248),
#  ('KiMr24804', 5, 5, 32311),
#  ('KiMr24804', 5, 5, 32338),
#  ('KiMr24804', 5, 5, 32428),
#  ('KiMr24804', 5, 5, 32527),
#  ('KiMr24804', 5, 5, 32563),
#  ('KiMr24804', 5, 5, 32691),
#  ('AmAm09946', 9, 9, 6947),
#  ('KiAm22279', 3, 3, 53988),
#  ('KiAm22279', 3, 3, 54039),
#  ('KiAm22279', 3, 3, 54070),
#  ('KiAm22279', 3, 3, 54207),
#  ('KiAm22279', 3, 3, 54256),
#  ('KiAm22279', 3, 3, 54283),
#  ('KiAm22279', 3, 3, 54316),
#  ('KiAm22279', 3, 3, 54439),
#  ('AkRu03992', 2, 2, 39531),
#  ('AmRu14758', 9, 9, 54230),
#  ('AmRu13619', 9, 9, 21143),
#  ('AmAm09492', 9, 9, 29419),
#  ('AkRu08500', 3, 3, 57702),
#  ('HaRu18780', 1, 1, 21375),
#  ('SoRu38398', 3, 3, 31256),
#  ('AmAm09540', 0, 0, 6674),
#  ('AkLu02114', 3, 3, 25130),
#  ('AmBe11296', 3, 3, 30535),
#  ('AmBe11296', 3, 3, 30603),
#  ('AmBe11296', 3, 3, 30701),
#  ('AmBe11296', 3, 3, 30733),
#  ('AmBe11296', 3, 3, 30780),
#  ('AmBe11296', 3, 3, 30851),
#  ('AmBe11296', 3, 3, 30884),
#  ('AmBe11296', 3, 3, 30963),
#  ('AkRu05627', 7, 7, 17619),
#  ('AkKi01158', 3, 3, 46022),
#  ('AkKi01158', 3, 3, 46098),
#  ('AkKi01158', 3, 3, 46151),
#  ('AkKi01158', 3, 3, 46227),
#  ('AkKi01158', 3, 3, 46231),
#  ('AkKi01158', 3, 3, 46299),
#  ('AkKi01158', 3, 3, 46377),
#  ('AkKi01158', 3, 3, 46430),
#  ('KiRu30069', 3, 3, 27180),
#  ('AmAm09774', 9, 9, 19982),
#  ('HaRu19731', 3, 3, 17066),
#  ('AkRu07991', 2, 2, 8013),
#  ('HaZa21811', 1, 1, 5954),
#  ('AmPw12299', 9, 9, 7643),
#  ('HaRu17417', 2, 2, 3105),
#  ('AmRu12818', 3, 3, 27250),
#  ('AmAm09730', 9, 9, 54871),
#  ('HaAm16072', 2, 2, 16938),
#  ('KiAm22564', 0, 0, 855),
#  ('AkRu04359', 3, 3, 37376),
#  ('AmRu14130', 2, 2, 33897),
#  ('AmPw12685', 3, 3, 42213),
#  ('KiIs23737', 9, 9, 26455),
#  ('AkRu05675', 3, 3, 37439),
#  ('KiRu27273', 3, 3, 586),
#  ('KiRu27273', 3, 3, 728),
#  ('KiRu27273', 3, 3, 766),
#  ('KiRu27273', 3, 3, 873),
#  ('KiRu27273', 3, 3, 913),
#  ('KiRu27273', 3, 3, 923),
#  ('KiRu27273', 3, 3, 956),
#  ('KiRu27273', 3, 3, 1023),
#  ('KiZu31183', 9, 9, 878),
#  ('HaZa21677', 1, 1, 21941),
#  ('AkKi01487', 1, 1, 26522),
#  ('AmDa12045', 5, 5, 28843),
#  ('AmDa12045', 5, 5, 28931),
#  ('AmDa12045', 5, 5, 29037),
#  ('AmDa12045', 5, 5, 29059),
#  ('AmDa12045', 5, 5, 29153),
#  ('AmDa12045', 5, 5, 29246),
#  ('AmDa12045', 5, 5, 29342),
#  ('AmDa12045', 5, 5, 29351),
#  ('HaDj16928', 2, 2, 8746),
#  ('SoIl32627', 3, 3, 57949),
#  ('AkRu03179', 5, 5, 10891),
#  ('AkRu03179', 5, 5, 10957),
#  ('AkRu03179', 5, 5, 11063),
#  ('AkRu03179', 5, 5, 11105),
#  ('AkRu03179', 5, 5, 11162),
#  ('AkRu03179', 5, 5, 11177),
#  ('AkRu03179', 5, 5, 11197),
#  ('AkRu03179', 5, 5, 11358),
#  ('AkRu05546', 0, 0, 42454),
#  ('AmAs10264', 9, 9, 13865),
#  ('AmAb08995', 9, 9, 50217),
#  ('AkRu06775', 2, 2, 39605),
#  ('SoRu35734', 2, 2, 6130),
#  ('AkRu05280', 3, 3, 6761),
#  ('SoRu35119', 2, 2, 56397),
#  ('KiRu25483', 6, 6, 11863),
#  ('KiAm22240', 9, 9, 28235),
#  ('AkRu06232', 2, 2, 51694),
#  ('KiRu25576', 6, 6, 32883),
#  ('SoRu39485', 1, 1, 29514),
#  ('AkRu07003', 3, 3, 43164),
#  ('SoRu38178', 3, 3, 19831),
#  ('HaRu18408', 3, 3, 37807),
#  ('HaRu18408', 3, 3, 37916),
#  ('HaRu18408', 3, 3, 37948),
#  ('HaRu18408', 3, 3, 38020),
#  ('HaRu18408', 3, 3, 38033),
#  ('HaRu18408', 3, 3, 38045),
#  ('HaRu18408', 3, 3, 38179),
#  ('HaRu18408', 3, 3, 38224),
#  ('KiRu26522', 3, 3, 7962),
#  ('KiRu28005', 2, 2, 39752),
#  ('AkRu08633', 3, 3, 19210),
#  ('AkLu01598', 2, 2, 23013),
#  ('AmPw12594', 9, 9, 24173),
#  ('SoRu39617', 9, 9, 11689),
#  ('HaRu18732', 2, 2, 30369),
#  ('AkRu04678', 3, 3, 36432),
#  ('AmRu15262', 0, 0, 43261),
#  ('KiZu30898', 3, 3, 59198),
#  ('KiZu30898', 3, 3, 59250),
#  ('KiZu30898', 3, 3, 59375),
#  ('KiZu30898', 3, 3, 59428),
#  ('KiZu30898', 3, 3, 59503),
#  ('KiZu30898', 3, 3, 59607),
#  ('KiZu30898', 3, 3, 59618),
#  ('KiZu30898', 3, 3, 59708),
#  ('AkRu06383', 3, 3, 15579),
#  ('AkRu06383', 3, 3, 15611),
#  ('AkRu06383', 3, 3, 15734),
#  ('AkRu06383', 3, 3, 15788),
#  ('AkRu06383', 3, 3, 15813),
#  ('AkRu06383', 3, 3, 15867),
#  ('AkRu06383', 3, 3, 16010),
#  ('AkRu06383', 3, 3, 16017),
#  ('KiRu29989', 9, 9, 13822),
#  ('SoRu35998', 1, 1, 38786),
#  ('AkRu04153', 2, 2, 10514),
#  ('SoMa34162', 3, 3, 32390),
#  ('KiRu29836', 7, 7, 10502),
#  ('SoRu35504', 2, 2, 24139),
#  ('SoRu35596', 9, 9, 4059),
#  ('AkRu04215', 1, 1, 28844),
#  ('HaZa21907', 1, 1, 21884),
#  ('AkRu05411', 0, 0, 42438),
#  ('AkKi01559', 3, 3, 26258),
#  ('KiMr24656', 1, 1, 40725),
#  ('HaRu17951', 3, 3, 45736),
#  ('KiRu29143', 7, 7, 39438),
#  ('AkRu04294', 9, 9, 24293),
#  ('SoKo33149', 1, 1, 47600),
#  ('AkRu04720', 2, 2, 4530),
#  ('KiRu25511', 9, 9, 26516),
#  ('SoRu35939', 1, 1, 55017),
#  ('HaRu17470', 1, 1, 19548),
#  ('KiAm22039', 3, 3, 59926),
#  ('KiAm22039', 3, 3, 60007),
#  ('KiAm22039', 3, 3, 60032),
#  ('KiAm22039', 3, 3, 60062),
#  ('KiAm22039', 3, 3, 60089),
#  ('KiAm22039', 3, 3, 60112),
#  ('KiAm22039', 3, 3, 60118),
#  ('KiAm22039', 3, 3, 60138),
#  ('SoRu38185', 2, 2, 15298),
#  ('KiMr25042', 4, 4, 3652),
#  ('SoRu37208', 1, 1, 7939),
#  ('AkKi01424', 3, 3, 11784),
#  ('AkRu03770', 7, 7, 55628),
#  ('HaZa21810', 1, 1, 11254),
#  ('AkRu03265', 3, 3, 52348),
#  ('AmAb09118', 2, 2, 54914),
#  ('AkKi01512', 3, 3, 5022),
#  ('AkRu05299', 2, 2, 25168),
#  ('AkKi00885', 3, 3, 5042),
#  ('HaRu20039', 1, 1, 26906),
#  ('AkKi01541', 3, 3, 7331),
#  ('AkHa00058', 3, 3, 11935),
#  ('SoRu36804', 4, 4, 18604),
#  ('AkRu06181', 6, 6, 22009),
#  ('KiRu30244', 1, 1, 48270),
#  ('SoRu35370', 0, 0, 20354),
#  ('KiHa22708', 2, 2, 28319),
#  ('AkKi01235', 0, 0, 17149),
#  ('HaRu17273', 1, 1, 55881),
#  ('SoRu35584', 2, 2, 54924),
#  ('HaRu17358', 2, 2, 54229),
#  ('HaYa21508', 2, 2, 2159),
#  ('SoRu36839', 3, 3, 46993),
#  ('SoRu36839', 3, 3, 47072),
#  ('SoRu36839', 3, 3, 47166),
#  ('SoRu36839', 3, 3, 47178),
#  ('SoRu36839', 3, 3, 47222),
#  ('SoRu36839', 3, 3, 47284),
#  ('SoRu36839', 3, 3, 47417),
#  ('SoRu36839', 3, 3, 47510),
#  ('HaAm15940', 0, 0, 16568),
#  ('KiHa23374', 2, 2, 39377),
#  ('KiRu25462', 2, 2, 21381),
#  ('SoRu39299', 1, 1, 53064),
#  ('AmRu15113', 3, 3, 44436),
#  ('KiRu25467', 0, 0, 30711),
#  ('KiMr25069', 3, 3, 47475),
#  ('HaRu18669', 1, 1, 51092),
#  ('KiMr24993', 9, 9, 32824),
#  ('KiRu29205', 5, 5, 50794),
#  ('KiRu29205', 5, 5, 50884),
#  ('KiRu29205', 5, 5, 50971),
#  ('KiRu29205', 5, 5, 50972),
#  ('KiRu29205', 5, 5, 51002),
#  ('KiRu29205', 5, 5, 51033),
#  ('KiRu29205', 5, 5, 51116),
#  ('KiRu29205', 5, 5, 51250),
#  ('AkRu04281', 0, 0, 26695),
#  ('AkRu03009', 2, 2, 19267),
#  ('AkRu07584', 0, 0, 38645),
#  ('KiAm22619', 3, 3, 27044),
#  ('KiHa23324', 1, 1, 54357),
#  ('SoCh32105', 0, 0, 48137),
#  ('SoRu36947', 6, 6, 39773),
#  ('AkKi01226', 2, 2, 34007),
#  ('SoMa34203', 9, 9, 22703),
#  ('AkRu07928', 3, 3, 40961),
#  ('AmAm09716', 3, 3, 8754),
#  ('KiRu26898', 2, 2, 19044),
#  ('SoRu35204', 3, 3, 18482),
#  ('SoRu38992', 1, 1, 45701),
#  ('KiRu29642', 2, 2, 2288),
#  ('KiAm22546', 0, 0, 24437),
#  ('AkRu08709', 4, 4, 11252),
#  ('AmBe11146', 9, 9, 31114),
#  ('SoRu38840', 9, 9, 55481),
#  ('HaSe20913', 9, 9, 13769),
#  ('AkRu06409', 3, 3, 45638),
#  ('KiAm22010', 9, 9, 45182),
#  ('KiRu28681', 2, 2, 47091),
#  ('KiRu27445', 0, 0, 51588),
#  ('KiMr25066', 2, 2, 58667),
#  ('AkRu08527', 2, 2, 20668),
#  ('AkRu03366', 3, 3, 10434),
#  ('AkRu03366', 3, 3, 10488),
#  ('AkRu03366', 3, 3, 10568),
#  ('AkRu03366', 3, 3, 10674),
#  ('AkRu03366', 3, 3, 10702),
#  ('AkRu03366', 3, 3, 10721),
#  ('AkRu03366', 3, 3, 10843),
#  ('AkRu03366', 3, 3, 10911),
#  ('AmAs10727', 3, 3, 20242),
#  ('SoCh32218', 9, 9, 51742),
#  ('HaAm16144', 2, 2, 39129),
#  ('HaDe16554', 9, 9, 8299),
#  ('KiRu28451', 1, 1, 59100),
#  ('SoRu36896', 4, 4, 22280),
#  ('HaYa21537', 9, 9, 4904),
#  ('AmBe11144', 9, 9, 46501),
#  ('AmAm09885', 9, 9, 21022),
#  ('AkRu04239', 2, 2, 36769),
#  ('AkRu03485', 2, 2, 54532),
#  ('HaRu20552', 9, 9, 45465),
#  ('KiRu26022', 9, 9, 44127),
#  ('SoRu37386', 5, 5, 40752),
#  ('KiRu27731', 3, 3, 2096),
#  ('AmRu14200', 1, 1, 27946),
#  ('AmRu14220', 3, 3, 54231),
#  ('HaRu18473', 2, 2, 35385),
#  ('KiRu28208', 3, 3, 23536),
#  ('AmPw12359', 9, 9, 24353),
#  ('KiIs23579', 2, 2, 55457),
#  ('SoRu36686', 9, 9, 5517),
#  ('HaRu17704', 2, 2, 14773),
#  ('AkRu07773', 3, 3, 36775),
#  ('HaRu19574', 3, 3, 4944),
#  ('HaRu19574', 3, 3, 4992),
#  ('HaRu19574', 3, 3, 5070),
#  ...]

# %% [markdown]
# We get a result of **2505** records, but remember that the auditor's records had **1620** records. This is because in the visits entity, various locations were visited more than once meaning that there are duplicate records in our resulting dataset. To remove the duplicate records we specify that we only want records of locations that were visited once in the `WHERE` clause

# %%
# %%sql
# SELECT
#     a.location_id AS auditor_location,
#     a.true_water_source_score AS auditor_score,
#     q.subjective_quality_score AS surveyor_score,
#     v.record_id
# FROM
#     auditor_report AS a
# JOIN
#     visits AS v
#     ON a.location_id = v.location_id
# JOIN
#     water_quality AS q
#     ON v.record_id = q.record_id
# WHERE
#     a.true_water_source_score = q.subjective_quality_score
# AND
#     v.visit_count = 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1518 rows affected.
# [('SoRu34980', 1, 1, 5185),
#  ('AkRu08112', 3, 3, 59367),
#  ('AkLu02044', 0, 0, 37379),
#  ('AkHa00421', 3, 3, 51627),
#  ('SoRu35221', 0, 0, 28758),
#  ('HaAm16170', 1, 1, 31048),
#  ('AkRu04812', 3, 3, 1513),
#  ('AkRu08304', 3, 3, 1218),
#  ('AkRu05107', 2, 2, 8322),
#  ('HaDe16541', 2, 2, 13070),
#  ('KiRu30351', 9, 9, 54220),
#  ('AmAm09813', 4, 4, 191),
#  ('SoRu37005', 0, 0, 51172),
#  ('KiRu26067', 3, 3, 21010),
#  ('SoRu37100', 0, 0, 40276),
#  ('AmDa11611', 1, 1, 38071),
#  ('AkRu07801', 3, 3, 25278),
#  ('KiZu31015', 3, 3, 47319),
#  ('KiIs24026', 2, 2, 2942),
#  ('AkRu08480', 2, 2, 47118),
#  ('AmBe11043', 3, 3, 53502),
#  ('AmRu13718', 9, 9, 31092),
#  ('AmRu15209', 3, 3, 42546),
#  ('SoRu37428', 3, 3, 25748),
#  ('SoRu34787', 2, 2, 30989),
#  ('AkRu03204', 3, 3, 36239),
#  ('SoMa34137', 3, 3, 4657),
#  ('SoRu38874', 3, 3, 17601),
#  ('KiMr24320', 2, 2, 9219),
#  ('AkRu06460', 2, 2, 42913),
#  ('KiRu28673', 1, 1, 57339),
#  ('AkHa00193', 9, 9, 25090),
#  ('AmAs10732', 0, 0, 53977),
#  ('KiRu27585', 3, 3, 2193),
#  ('AkRu03541', 2, 2, 23766),
#  ('AkRu04448', 3, 3, 55253),
#  ('HaRu20155', 0, 0, 56131),
#  ('AmAm09990', 5, 5, 3820),
#  ('KiZu31024', 0, 0, 53881),
#  ('SoIl32392', 3, 3, 2825),
#  ('SoRu38699', 3, 3, 13821),
#  ('KiAm22079', 9, 9, 50732),
#  ('KiRu26316', 3, 3, 27240),
#  ('AkKi01456', 9, 9, 57050),
#  ('AkRu08152', 2, 2, 43992),
#  ('KiRu27444', 7, 7, 18928),
#  ('HaRu20693', 1, 1, 55091),
#  ('AkRu04981', 3, 3, 8803),
#  ('KiRu28580', 1, 1, 14177),
#  ('KiRu30008', 1, 1, 25914),
#  ('SoMa34631', 2, 2, 55851),
#  ('SoKo33227', 1, 1, 31236),
#  ('AmRu14465', 3, 3, 23398),
#  ('AkHa00008', 3, 3, 57788),
#  ('HaRu19826', 9, 9, 55626),
#  ('AmDa11947', 1, 1, 23857),
#  ('AmPw12680', 3, 3, 45472),
#  ('HaDe16514', 1, 1, 42469),
#  ('KiMr24591', 0, 0, 44892),
#  ('KiIs24014', 1, 1, 36889),
#  ('AkRu07523', 3, 3, 22404),
#  ('AkRu04753', 9, 9, 55958),
#  ('SoRu36774', 2, 2, 35173),
#  ('SoRu36239', 2, 2, 43524),
#  ('KiRu27776', 3, 3, 23770),
#  ('AkRu03164', 3, 3, 42866),
#  ('AkRu05809', 2, 2, 8004),
#  ('KiRu28632', 5, 5, 32143),
#  ('KiRu30389', 4, 4, 17755),
#  ('AkKi01375', 3, 3, 40201),
#  ('SoRu37530', 0, 0, 55624),
#  ('AmBe10959', 4, 4, 23719),
#  ('HaRu19828', 2, 2, 25621),
#  ('SoIl32999', 2, 2, 32992),
#  ('HaRu18571', 2, 2, 56000),
#  ('AkRu08666', 6, 6, 56276),
#  ('AkRu03306', 7, 7, 29135),
#  ('AkRu08936', 3, 3, 132),
#  ('HaSe21341', 3, 3, 59324),
#  ('SoRu35327', 1, 1, 59821),
#  ('AmRu14903', 9, 9, 54574),
#  ('AmAb09101', 6, 6, 10635),
#  ('KiAm22276', 0, 0, 15269),
#  ('HaRu20617', 1, 1, 18740),
#  ('HaRu18217', 1, 1, 58386),
#  ('KiRu29806', 9, 9, 35488),
#  ('KiRu28057', 1, 1, 25822),
#  ('AkRu06170', 3, 3, 16253),
#  ('AkRu03380', 3, 3, 45718),
#  ('KiRu26678', 2, 2, 17842),
#  ('AmBe10942', 9, 9, 23182),
#  ('KiIs23730', 3, 3, 59182),
#  ('KiHa23034', 3, 3, 39514),
#  ('KiRu28090', 6, 6, 493),
#  ('AmRu13729', 2, 2, 12421),
#  ('HaRu18016', 1, 1, 43421),
#  ('KiRu27440', 9, 9, 46897),
#  ('HaYa21606', 3, 3, 54414),
#  ('HaRu17207', 1, 1, 41291),
#  ('AmAm09735', 1, 1, 19578),
#  ('HaRu20534', 2, 2, 36976),
#  ('AmPw12770', 3, 3, 57820),
#  ('AkLu02096', 3, 3, 46932),
#  ('HaRu20434', 2, 2, 26351),
#  ('AkRu02688', 0, 0, 28038),
#  ('AmBe11285', 9, 9, 30594),
#  ('AmRu13720', 3, 3, 57704),
#  ('SoMa33819', 0, 0, 41990),
#  ('SoRu38119', 1, 1, 32719),
#  ('AmRu12983', 3, 3, 34259),
#  ('SoRu35906', 5, 5, 23263),
#  ('KiRu27742', 3, 3, 20199),
#  ('SoRu35991', 3, 3, 49145),
#  ('KiRu28083', 4, 4, 28642),
#  ('AmRu15159', 9, 9, 3238),
#  ('HaYa21456', 2, 2, 31258),
#  ('HaRu18734', 2, 2, 9967),
#  ('SoRu35970', 3, 3, 49787),
#  ('AmAs10285', 3, 3, 35054),
#  ('KiZu31223', 3, 3, 45820),
#  ('SoRu38546', 9, 9, 31987),
#  ('AmPw12293', 6, 6, 43323),
#  ('SoRu39488', 3, 3, 778),
#  ('SoRu39408', 5, 5, 9997),
#  ('HaRu17750', 2, 2, 55863),
#  ('KiRu30604', 0, 0, 38650),
#  ('KiZu30905', 9, 9, 38879),
#  ('SoRu39374', 9, 9, 12919),
#  ('SoRu37406', 2, 2, 36882),
#  ('AkRu05212', 9, 9, 41421),
#  ('SoIl32294', 0, 0, 58139),
#  ('AmBe11313', 0, 0, 12271),
#  ('SoRu35426', 3, 3, 12319),
#  ('AkHa00073', 3, 3, 13554),
#  ('SoRu35899', 9, 9, 10054),
#  ('KiRu26664', 2, 2, 30561),
#  ('SoRu36580', 3, 3, 15465),
#  ('AkLu02432', 2, 2, 56526),
#  ('HaRu19287', 5, 5, 54666),
#  ('SoRu38915', 1, 1, 26133),
#  ('KiRu26032', 0, 0, 12342),
#  ('KiRu25619', 3, 3, 48832),
#  ('AkHa00172', 2, 2, 41191),
#  ('KiRu27927', 3, 3, 33105),
#  ('KiRu28045', 2, 2, 16862),
#  ('KiRu29614', 1, 1, 51573),
#  ('KiRu25484', 1, 1, 20447),
#  ('AkRu04989', 1, 1, 34369),
#  ('AkKi01455', 3, 3, 16750),
#  ('SoIl33047', 2, 2, 45984),
#  ('SoCh32025', 0, 0, 14252),
#  ('KiRu28089', 0, 0, 9134),
#  ('AkRu07622', 2, 2, 18841),
#  ('KiRu29909', 1, 1, 28639),
#  ('AmBe11266', 9, 9, 6032),
#  ('KiRu26934', 2, 2, 44733),
#  ('SoRu35691', 5, 5, 13341),
#  ('SoMa34148', 2, 2, 50300),
#  ('AmRu15860', 1, 1, 46070),
#  ('SoRu38125', 5, 5, 26141),
#  ('AkLu02637', 9, 9, 13812),
#  ('SoRu35824', 1, 1, 28362),
#  ('KiRu27806', 0, 0, 42076),
#  ('AkRu03182', 3, 3, 13651),
#  ('AkHa00088', 1, 1, 12774),
#  ('SoRu36828', 2, 2, 5668),
#  ('AkLu02438', 9, 9, 24429),
#  ('SoRu38250', 6, 6, 21140),
#  ('AkHa00613', 3, 3, 20924),
#  ('KiMr25005', 0, 0, 58102),
#  ('AkRu04428', 3, 3, 9203),
#  ('SoRu35103', 5, 5, 44051),
#  ('SoRu36975', 0, 0, 26255),
#  ('AkHa00662', 2, 2, 52082),
#  ('SoCh31985', 3, 3, 37231),
#  ('SoRu37129', 0, 0, 31642),
#  ('SoRu38416', 3, 3, 49607),
#  ('AkRu02670', 2, 2, 8346),
#  ('AkHa00487', 3, 3, 14442),
#  ('SoRu36186', 0, 0, 16286),
#  ('AkRu03649', 2, 2, 4101),
#  ('SoMa34044', 0, 0, 20902),
#  ('AmRu14531', 9, 9, 13172),
#  ('SoRu37317', 2, 2, 50347),
#  ('KiIs23613', 6, 6, 3093),
#  ('SoRu39288', 0, 0, 13409),
#  ('AkRu07820', 3, 3, 34009),
#  ('AkRu07774', 3, 3, 24774),
#  ('SoRu36385', 2, 2, 54896),
#  ('KiIs24054', 9, 9, 21978),
#  ('KiRu29129', 1, 1, 32520),
#  ('KiHa23042', 1, 1, 54900),
#  ('AkHa00459', 1, 1, 39863),
#  ('SoBa31659', 3, 3, 17354),
#  ('KiRu30394', 4, 4, 6624),
#  ('SoKo33111', 1, 1, 19195),
#  ('AkRu03429', 3, 3, 17142),
#  ('KiRu26860', 0, 0, 24912),
#  ('KiAm22303', 9, 9, 56325),
#  ('HaRu18493', 3, 3, 25264),
#  ('HaRu18608', 1, 1, 4779),
#  ('SoRu35964', 2, 2, 58643),
#  ('KiMr24872', 2, 2, 47577),
#  ('KiAm22458', 2, 2, 672),
#  ('AkRu05603', 3, 3, 54483),
#  ('HaRu20851', 9, 9, 56353),
#  ('KiRu25343', 1, 1, 41757),
#  ('SoRu36816', 3, 3, 57218),
#  ('HaRu20840', 3, 3, 43798),
#  ('SoRu38966', 5, 5, 3240),
#  ('SoRu37494', 9, 9, 17009),
#  ('HaRu19176', 1, 1, 25331),
#  ('AmBe11175', 3, 3, 22982),
#  ('HaDe16360', 1, 1, 19732),
#  ('AmBe11054', 9, 9, 8225),
#  ('AkRu08460', 2, 2, 59776),
#  ('SoKo33124', 3, 3, 2006),
#  ('AkKi01211', 3, 3, 16824),
#  ('SoIl32445', 2, 2, 25386),
#  ('AmRu13532', 9, 9, 39886),
#  ('SoRu36142', 1, 1, 7542),
#  ('AkRu05020', 3, 3, 4291),
#  ('HaRu18730', 1, 1, 34773),
#  ('KiRu25527', 2, 2, 30088),
#  ('AkRu05442', 3, 3, 59724),
#  ('AkRu05207', 3, 3, 53713),
#  ('AmAm09844', 9, 9, 39550),
#  ('AkRu04217', 3, 3, 18145),
#  ('SoRu38733', 5, 5, 16689),
#  ('SoBa31655', 9, 9, 5710),
#  ('SoRu37392', 4, 4, 17821),
#  ('AkKi01238', 3, 3, 15839),
#  ('AmRu14527', 3, 3, 36952),
#  ('KiRu26502', 3, 3, 9396),
#  ('AkRu06339', 0, 0, 28338),
#  ('SoRu37920', 0, 0, 42676),
#  ('AkRu02682', 2, 2, 26484),
#  ('AmBe10969', 3, 3, 39852),
#  ('AkRu08755', 3, 3, 19813),
#  ('KiRu30051', 2, 2, 13174),
#  ('HaRu19054', 2, 2, 314),
#  ('HaRu17182', 1, 1, 26851),
#  ('AmBe11275', 3, 3, 26263),
#  ('HaRu19036', 2, 2, 52668),
#  ('KiMr24348', 2, 2, 40090),
#  ('AmPw12550', 9, 9, 28247),
#  ('HaRu20299', 2, 2, 43586),
#  ('KiRu29119', 1, 1, 25652),
#  ('AkRu03116', 3, 3, 32365),
#  ('SoRu35393', 1, 1, 23001),
#  ('AkLu02173', 1, 1, 27091),
#  ('AkRu08283', 3, 3, 45092),
#  ('KiRu28782', 3, 3, 58809),
#  ('AmAs10095', 3, 3, 46365),
#  ('KiRu29980', 1, 1, 5321),
#  ('KiRu25770', 3, 3, 37346),
#  ('AmRu15634', 3, 3, 24374),
#  ('AkRu07742', 2, 2, 3469),
#  ('KiRu28806', 1, 1, 26429),
#  ('AmAs10011', 9, 9, 44726),
#  ('KiMr25056', 1, 1, 36815),
#  ('HaDj16864', 1, 1, 25972),
#  ('HaRu18271', 1, 1, 14781),
#  ('HaAm16293', 3, 3, 55255),
#  ('KiRu27852', 2, 2, 30754),
#  ('AmAs10552', 9, 9, 16840),
#  ('HaAm16112', 2, 2, 15506),
#  ('KiZu30983', 3, 3, 5702),
#  ('HaYa21356', 2, 2, 36919),
#  ('AkRu03754', 3, 3, 6493),
#  ('SoMa34566', 2, 2, 39478),
#  ('AmRu15394', 1, 1, 15192),
#  ('HaRu19917', 9, 9, 53947),
#  ('SoRu35762', 1, 1, 47342),
#  ('AmAm09806', 9, 9, 41269),
#  ('AmAm09566', 9, 9, 37437),
#  ('KiRu27527', 2, 2, 30396),
#  ('SoRu36079', 0, 0, 41487),
#  ('AkLu02420', 2, 2, 46052),
#  ('SoRu38360', 0, 0, 30990),
#  ('KiIs23815', 2, 2, 15619),
#  ('AkLu01944', 3, 3, 29104),
#  ('SoBa31866', 1, 1, 15628),
#  ('AkRu05799', 3, 3, 53738),
#  ('KiRu26647', 1, 1, 31416),
#  ('AmRu14452', 3, 3, 3138),
#  ('AkRu03095', 3, 3, 59212),
#  ('SoRu37072', 1, 1, 34917),
#  ('SoBa31473', 2, 2, 18821),
#  ('SoRu35606', 3, 3, 3368),
#  ('KiRu28515', 2, 2, 48699),
#  ('KiMr24897', 9, 9, 17117),
#  ('AkRu03657', 2, 2, 56435),
#  ('AmAs10840', 9, 9, 9908),
#  ('SoRu37224', 2, 2, 30665),
#  ('HaRu20820', 2, 2, 43257),
#  ('KiIs23717', 3, 3, 18330),
#  ('HaRu18196', 1, 1, 51823),
#  ('KiRu28445', 1, 1, 9213),
#  ('AkRu04790', 9, 9, 2023),
#  ('AkLu01749', 3, 3, 37485),
#  ('SoRu35924', 2, 2, 36027),
#  ('KiRu27827', 2, 2, 48940),
#  ('AmRu13018', 5, 5, 34248),
#  ('SoRu36421', 0, 0, 20600),
#  ('KiRu28584', 1, 1, 52713),
#  ('KiRu29073', 2, 2, 28511),
#  ('AkHa00593', 2, 2, 29731),
#  ('AkKi01372', 3, 3, 49534),
#  ('AkLu02206', 3, 3, 4533),
#  ('AkRu08105', 2, 2, 25512),
#  ('AkRu04781', 2, 2, 56179),
#  ('KiRu27348', 1, 1, 56646),
#  ('AkRu07358', 3, 3, 50252),
#  ('SoRu35645', 3, 3, 17917),
#  ('HaDj16729', 1, 1, 44405),
#  ('AmAm09422', 9, 9, 28365),
#  ('KiRu28871', 9, 9, 46572),
#  ('SoKo33489', 2, 2, 21867),
#  ('KiIs24061', 2, 2, 42529),
#  ('SoRu36514', 6, 6, 33109),
#  ('SoRu38062', 0, 0, 55400),
#  ('AkRu04644', 3, 3, 51404),
#  ('AkRu07669', 2, 2, 6875),
#  ('KiMr24651', 3, 3, 54735),
#  ('SoRu35689', 0, 0, 44968),
#  ('KiZu31427', 9, 9, 22019),
#  ('KiMr24677', 1, 1, 57585),
#  ('HaRu17145', 1, 1, 58460),
#  ('SoKo33450', 2, 2, 52145),
#  ('AkRu06471', 2, 2, 22708),
#  ('AkRu03909', 6, 6, 48225),
#  ('SoRu38054', 0, 0, 36448),
#  ('KiZu30933', 0, 0, 10930),
#  ('AmRu15659', 3, 3, 21540),
#  ('AkRu04196', 1, 1, 6317),
#  ('HaRu17171', 3, 3, 56405),
#  ('KiZu31286', 5, 5, 58243),
#  ('KiRu27045', 9, 9, 25122),
#  ('AkRu07822', 2, 2, 38982),
#  ('SoRu38801', 5, 5, 30299),
#  ('AkRu05622', 2, 2, 37033),
#  ('AmRu13368', 3, 3, 59978),
#  ('KiRu29197', 2, 2, 3862),
#  ('KiHa22987', 2, 2, 51906),
#  ('AmAb09209', 0, 0, 2528),
#  ('SoRu35737', 1, 1, 12880),
#  ('HaRu20358', 1, 1, 32243),
#  ('SoRu38427', 0, 0, 27985),
#  ('SoRu39385', 2, 2, 26100),
#  ('KiAm22078', 3, 3, 14154),
#  ('HaRu18624', 2, 2, 571),
#  ('AkLu01620', 3, 3, 52324),
#  ('SoRu39442', 0, 0, 40218),
#  ('AmBe11161', 3, 3, 16638),
#  ('SoRu36982', 9, 9, 59694),
#  ('KiRu29202', 3, 3, 42496),
#  ('KiRu30289', 1, 1, 2112),
#  ('HaDj16691', 3, 3, 43418),
#  ('SoRu35904', 0, 0, 11602),
#  ('AkRu07627', 7, 7, 38984),
#  ('AkRu06941', 9, 9, 12025),
#  ('SoMa33925', 1, 1, 40620),
#  ('KiAm22052', 3, 3, 25833),
#  ('SoRu37929', 0, 0, 52815),
#  ('HaRu19467', 1, 1, 5732),
#  ('HaRu19164', 1, 1, 51451),
#  ('HaRu18836', 9, 9, 58049),
#  ('SoRu38150', 9, 9, 57491),
#  ('AmAm09853', 9, 9, 41120),
#  ('SoRu38947', 2, 2, 30376),
#  ('AmDa11683', 4, 4, 44700),
#  ('AmRu14207', 1, 1, 32491),
#  ('HaZa21638', 1, 1, 12606),
#  ('KiRu30052', 2, 2, 45489),
#  ('KiRu26263', 9, 9, 30172),
#  ('AmAb08975', 9, 9, 25976),
#  ('SoRu38924', 9, 9, 14792),
#  ('KiRu26698', 9, 9, 32554),
#  ('KiRu26909', 3, 3, 48857),
#  ('SoCh32037', 0, 0, 17084),
#  ('SoMa33775', 0, 0, 9767),
#  ('HaRu20481', 2, 2, 43336),
#  ('KiRu29745', 2, 2, 47317),
#  ('KiRu29612', 2, 2, 2867),
#  ('AmRu13754', 9, 9, 35709),
#  ('SoRu35482', 0, 0, 26148),
#  ('HaRu17297', 9, 9, 15430),
#  ('AkRu03158', 9, 9, 48151),
#  ('AkRu06069', 7, 7, 33352),
#  ('KiRu26010', 1, 1, 17435),
#  ('KiRu28019', 2, 2, 1195),
#  ('KiRu30518', 3, 3, 41822),
#  ('AkRu07026', 9, 9, 38714),
#  ('KiRu26412', 0, 0, 52839),
#  ('SoRu35634', 3, 3, 19157),
#  ('AkHa00746', 1, 1, 21385),
#  ('SoIl33036', 1, 1, 43651),
#  ('AkRu06836', 1, 1, 40555),
#  ('HaRu19773', 9, 9, 50727),
#  ('KiMr24471', 0, 0, 21173),
#  ('KiRu28420', 1, 1, 58254),
#  ('AkRu07739', 3, 3, 17453),
#  ('KiRu27252', 2, 2, 51552),
#  ('KiIs23560', 1, 1, 42504),
#  ('KiRu25537', 3, 3, 38191),
#  ('KiHa23219', 2, 2, 36052),
#  ('AkLu02008', 0, 0, 56663),
#  ('SoMa34421', 3, 3, 30111),
#  ('SoRu37753', 2, 2, 31486),
#  ('AmPw12576', 7, 7, 9330),
#  ('AmRu13851', 3, 3, 16435),
#  ('KiMr24804', 5, 5, 32189),
#  ('AmAm09946', 9, 9, 6947),
#  ('KiAm22279', 3, 3, 53988),
#  ('AkRu03992', 2, 2, 39531),
#  ('AmRu14758', 9, 9, 54230),
#  ('AmRu13619', 9, 9, 21143),
#  ('AmAm09492', 9, 9, 29419),
#  ('AkRu08500', 3, 3, 57702),
#  ('HaRu18780', 1, 1, 21375),
#  ('SoRu38398', 3, 3, 31256),
#  ('AmAm09540', 0, 0, 6674),
#  ('AkLu02114', 3, 3, 25130),
#  ('AmBe11296', 3, 3, 30535),
#  ('AkRu05627', 7, 7, 17619),
#  ('AkKi01158', 3, 3, 46022),
#  ('KiRu30069', 3, 3, 27180),
#  ('AmAm09774', 9, 9, 19982),
#  ('HaRu19731', 3, 3, 17066),
#  ('AkRu07991', 2, 2, 8013),
#  ('HaZa21811', 1, 1, 5954),
#  ('AmPw12299', 9, 9, 7643),
#  ('HaRu17417', 2, 2, 3105),
#  ('AmRu12818', 3, 3, 27250),
#  ('AmAm09730', 9, 9, 54871),
#  ('HaAm16072', 2, 2, 16938),
#  ('KiAm22564', 0, 0, 855),
#  ('AkRu04359', 3, 3, 37376),
#  ('AmRu14130', 2, 2, 33897),
#  ('AmPw12685', 3, 3, 42213),
#  ('KiIs23737', 9, 9, 26455),
#  ('AkRu05675', 3, 3, 37439),
#  ('KiRu27273', 3, 3, 586),
#  ('KiZu31183', 9, 9, 878),
#  ('HaZa21677', 1, 1, 21941),
#  ('AkKi01487', 1, 1, 26522),
#  ('AmDa12045', 5, 5, 28843),
#  ('HaDj16928', 2, 2, 8746),
#  ('SoIl32627', 3, 3, 57949),
#  ('AkRu03179', 5, 5, 10891),
#  ('AkRu05546', 0, 0, 42454),
#  ('AmAs10264', 9, 9, 13865),
#  ('AmAb08995', 9, 9, 50217),
#  ('AkRu06775', 2, 2, 39605),
#  ('SoRu35734', 2, 2, 6130),
#  ('AkRu05280', 3, 3, 6761),
#  ('SoRu35119', 2, 2, 56397),
#  ('KiRu25483', 6, 6, 11863),
#  ('KiAm22240', 9, 9, 28235),
#  ('AkRu06232', 2, 2, 51694),
#  ('KiRu25576', 6, 6, 32883),
#  ('SoRu39485', 1, 1, 29514),
#  ('AkRu07003', 3, 3, 43164),
#  ('SoRu38178', 3, 3, 19831),
#  ('HaRu18408', 3, 3, 37807),
#  ('KiRu26522', 3, 3, 7962),
#  ('KiRu28005', 2, 2, 39752),
#  ('AkRu08633', 3, 3, 19210),
#  ('AkLu01598', 2, 2, 23013),
#  ('AmPw12594', 9, 9, 24173),
#  ('SoRu39617', 9, 9, 11689),
#  ('HaRu18732', 2, 2, 30369),
#  ('AkRu04678', 3, 3, 36432),
#  ('AmRu15262', 0, 0, 43261),
#  ('KiZu30898', 3, 3, 59198),
#  ('AkRu06383', 3, 3, 15579),
#  ('KiRu29989', 9, 9, 13822),
#  ('SoRu35998', 1, 1, 38786),
#  ('AkRu04153', 2, 2, 10514),
#  ('SoMa34162', 3, 3, 32390),
#  ('KiRu29836', 7, 7, 10502),
#  ('SoRu35504', 2, 2, 24139),
#  ('SoRu35596', 9, 9, 4059),
#  ('AkRu04215', 1, 1, 28844),
#  ('HaZa21907', 1, 1, 21884),
#  ('AkRu05411', 0, 0, 42438),
#  ('AkKi01559', 3, 3, 26258),
#  ('KiMr24656', 1, 1, 40725),
#  ('HaRu17951', 3, 3, 45736),
#  ('KiRu29143', 7, 7, 39438),
#  ('AkRu04294', 9, 9, 24293),
#  ('SoKo33149', 1, 1, 47600),
#  ('AkRu04720', 2, 2, 4530),
#  ('KiRu25511', 9, 9, 26516),
#  ('SoRu35939', 1, 1, 55017),
#  ('HaRu17470', 1, 1, 19548),
#  ('KiAm22039', 3, 3, 59926),
#  ('SoRu38185', 2, 2, 15298),
#  ('KiMr25042', 4, 4, 3652),
#  ('SoRu37208', 1, 1, 7939),
#  ('AkKi01424', 3, 3, 11784),
#  ('AkRu03770', 7, 7, 55628),
#  ('HaZa21810', 1, 1, 11254),
#  ('AkRu03265', 3, 3, 52348),
#  ('AmAb09118', 2, 2, 54914),
#  ('AkKi01512', 3, 3, 5022),
#  ('AkRu05299', 2, 2, 25168),
#  ('AkKi00885', 3, 3, 5042),
#  ('HaRu20039', 1, 1, 26906),
#  ('AkKi01541', 3, 3, 7331),
#  ('AkHa00058', 3, 3, 11935),
#  ('SoRu36804', 4, 4, 18604),
#  ('AkRu06181', 6, 6, 22009),
#  ('KiRu30244', 1, 1, 48270),
#  ('SoRu35370', 0, 0, 20354),
#  ('KiHa22708', 2, 2, 28319),
#  ('AkKi01235', 0, 0, 17149),
#  ('HaRu17273', 1, 1, 55881),
#  ('SoRu35584', 2, 2, 54924),
#  ('HaRu17358', 2, 2, 54229),
#  ('HaYa21508', 2, 2, 2159),
#  ('SoRu36839', 3, 3, 46993),
#  ('HaAm15940', 0, 0, 16568),
#  ('KiHa23374', 2, 2, 39377),
#  ('KiRu25462', 2, 2, 21381),
#  ('SoRu39299', 1, 1, 53064),
#  ('AmRu15113', 3, 3, 44436),
#  ('KiRu25467', 0, 0, 30711),
#  ('KiMr25069', 3, 3, 47475),
#  ('HaRu18669', 1, 1, 51092),
#  ('KiMr24993', 9, 9, 32824),
#  ('KiRu29205', 5, 5, 50794),
#  ('AkRu04281', 0, 0, 26695),
#  ('AkRu03009', 2, 2, 19267),
#  ('AkRu07584', 0, 0, 38645),
#  ('KiAm22619', 3, 3, 27044),
#  ('KiHa23324', 1, 1, 54357),
#  ('SoCh32105', 0, 0, 48137),
#  ('SoRu36947', 6, 6, 39773),
#  ('AkKi01226', 2, 2, 34007),
#  ('SoMa34203', 9, 9, 22703),
#  ('AkRu07928', 3, 3, 40961),
#  ('AmAm09716', 3, 3, 8754),
#  ('KiRu26898', 2, 2, 19044),
#  ('SoRu35204', 3, 3, 18482),
#  ('SoRu38992', 1, 1, 45701),
#  ('KiRu29642', 2, 2, 2288),
#  ('KiAm22546', 0, 0, 24437),
#  ('AkRu08709', 4, 4, 11252),
#  ('AmBe11146', 9, 9, 31114),
#  ('SoRu38840', 9, 9, 55481),
#  ('HaSe20913', 9, 9, 13769),
#  ('AkRu06409', 3, 3, 45638),
#  ('KiAm22010', 9, 9, 45182),
#  ('KiRu28681', 2, 2, 47091),
#  ('KiRu27445', 0, 0, 51588),
#  ('KiMr25066', 2, 2, 58667),
#  ('AkRu08527', 2, 2, 20668),
#  ('AkRu03366', 3, 3, 10434),
#  ('AmAs10727', 3, 3, 20242),
#  ('SoCh32218', 9, 9, 51742),
#  ('HaAm16144', 2, 2, 39129),
#  ('HaDe16554', 9, 9, 8299),
#  ('KiRu28451', 1, 1, 59100),
#  ('SoRu36896', 4, 4, 22280),
#  ('HaYa21537', 9, 9, 4904),
#  ('AmBe11144', 9, 9, 46501),
#  ('AmAm09885', 9, 9, 21022),
#  ('AkRu04239', 2, 2, 36769),
#  ('AkRu03485', 2, 2, 54532),
#  ('HaRu20552', 9, 9, 45465),
#  ('KiRu26022', 9, 9, 44127),
#  ('SoRu37386', 5, 5, 40752),
#  ('KiRu27731', 3, 3, 2096),
#  ('AmRu14200', 1, 1, 27946),
#  ('AmRu14220', 3, 3, 54231),
#  ('HaRu18473', 2, 2, 35385),
#  ('KiRu28208', 3, 3, 23536),
#  ('AmPw12359', 9, 9, 24353),
#  ('KiIs23579', 2, 2, 55457),
#  ('SoRu36686', 9, 9, 5517),
#  ('HaRu17704', 2, 2, 14773),
#  ('AkRu07773', 3, 3, 36775),
#  ('HaRu19574', 3, 3, 4944),
#  ('SoRu35147', 2, 2, 6783),
#  ('KiRu25784', 3, 3, 49705),
#  ('HaRu20497', 3, 3, 45862),
#  ('SoRu35551', 9, 9, 21557),
#  ('AkLu02036', 9, 9, 31106),
#  ('KiRu28450', 1, 1, 51366),
#  ('AkRu05101', 3, 3, 22180),
#  ('AmRu14915', 0, 0, 851),
#  ('SoRu38818', 0, 0, 23620),
#  ('KiRu25975', 1, 1, 33358),
#  ('HaRu19522', 1, 1, 39998),
#  ('AkRu08361', 3, 3, 10065),
#  ('HaRu19320', 2, 2, 43233),
#  ('KiRu26049', 2, 2, 4715),
#  ('KiAm22582', 2, 2, 31113),
#  ('HaAm16010', 5, 5, 15159),
#  ('SoRu37252', 2, 2, 31183),
#  ('KiRu28377', 2, 2, 18416),
#  ('HaDj16807', 9, 9, 11751),
#  ('HaRu20530', 2, 2, 28943),
#  ('HaRu20853', 3, 3, 6004),
#  ('KiZu31112', 1, 1, 22569),
#  ('SoRu36282', 2, 2, 55911),
#  ('AmDa11755', 7, 7, 2824),
#  ('KiAm22311', 3, 3, 58857),
#  ('KiMr24308', 3, 3, 58060),
#  ('AmRu13413', 3, 3, 8566),
#  ('AmAs10324', 9, 9, 57469),
#  ('KiRu27828', 1, 1, 47257),
#  ('SoIl32437', 3, 3, 18615),
#  ('AkRu04426', 2, 2, 52998),
#  ('AkRu06169', 3, 3, 34367),
#  ('AkRu02962', 3, 3, 11601),
#  ('HaRu19669', 2, 2, 28842),
#  ('KiMr25223', 1, 1, 3780),
#  ('HaRu20816', 1, 1, 55072),
#  ('AmRu13356', 9, 9, 42305),
#  ('KiIs23593', 1, 1, 29137),
#  ('AmAm09674', 9, 9, 49221),
#  ('SoRu39643', 1, 1, 17397),
#  ('AmRu15683', 9, 9, 21444),
#  ('AkRu05848', 3, 3, 34427),
#  ('AkLu02496', 3, 3, 20996),
#  ('SoRu38216', 3, 3, 31942),
#  ('KiRu30508', 1, 1, 5769),
#  ('KiRu27437', 4, 4, 44096),
#  ('KiRu28942', 2, 2, 27610),
#  ('KiAm22113', 3, 3, 20090),
#  ('AkRu04557', 3, 3, 13998),
#  ('HaRu18150', 1, 1, 21900),
#  ('AmRu15160', 2, 2, 46378),
#  ('HaRu20728', 1, 1, 41486),
#  ('KiRu26051', 3, 3, 14632),
#  ('KiRu28827', 1, 1, 56602),
#  ('HaRu17079', 3, 3, 25034),
#  ('KiRu29851', 3, 3, 47308),
#  ('AkRu08820', 3, 3, 55696),
#  ('AkRu06788', 3, 3, 27722),
#  ('AmRu13599', 9, 9, 6513),
#  ('SoMa34196', 9, 9, 42105),
#  ('AmRu15096', 9, 9, 58588),
#  ('SoIl32791', 0, 0, 4995),
#  ('AmBe11095', 9, 9, 17298),
#  ('AmAs10055', 6, 6, 33553),
#  ('AmAs10340', 9, 9, 32735),
#  ('SoRu35914', 2, 2, 23249),
#  ('SoRu36773', 1, 1, 43828),
#  ('KiHa23146', 7, 7, 48470),
#  ('SoRu35843', 0, 0, 31380),
#  ('AmDa12143', 3, 3, 28722),
#  ('HaRu18377', 4, 4, 3430),
#  ('KiMr25238', 3, 3, 39024),
#  ('AkHa00453', 3, 3, 47752),
#  ('SoRu36476', 3, 3, 19772),
#  ('KiRu26765', 3, 3, 41535),
#  ('AmBe11088', 5, 5, 58003),
#  ('KiZu31050', 2, 2, 48993),
#  ('KiRu30321', 2, 2, 51245),
#  ('SoRu38869', 3, 3, 4090),
#  ('AmAs10935', 3, 3, 45826),
#  ('SoRu37885', 3, 3, 19681),
#  ('KiRu25876', 1, 1, 1964),
#  ('AkRu06814', 2, 2, 12795),
#  ('KiRu25869', 3, 3, 22974),
#  ('AmAs10230', 2, 2, 13193),
#  ('AmRu14595', 3, 3, 53772),
#  ('KiAm21997', 9, 9, 26206),
#  ('SoRu35287', 2, 2, 19735),
#  ('SoRu36884', 0, 0, 51390),
#  ('HaRu19312', 2, 2, 5784),
#  ('SoRu39304', 0, 0, 46806),
#  ('KiZu30908', 0, 0, 29097),
#  ('AmAm09821', 0, 0, 54304),
#  ('AkRu03660', 3, 3, 55224),
#  ('AkHa00113', 3, 3, 4867),
#  ('KiRu28313', 2, 2, 21925),
#  ('SoBa31598', 3, 3, 47530),
#  ('KiRu26657', 9, 9, 55644),
#  ('AkRu04314', 0, 0, 48332),
#  ('HaAm16199', 1, 1, 4250),
#  ('KiRu28294', 5, 5, 37375),
#  ('AkRu08008', 2, 2, 27739),
#  ('HaRu18060', 1, 1, 3519),
#  ('AmRu14948', 3, 3, 37927),
#  ('SoCh32004', 1, 1, 6508),
#  ('AmRu14988', 2, 2, 7112),
#  ('AmRu13124', 9, 9, 8788),
#  ('AkRu03153', 3, 3, 6333),
#  ('HaSe21212', 3, 3, 47129),
#  ('SoRu36289', 1, 1, 8115),
#  ('AkLu02228', 2, 2, 14066),
#  ('AkRu08808', 6, 6, 51357),
#  ('AmAb09153', 6, 6, 51066),
#  ('AmRu15793', 2, 2, 48468),
#  ('KiRu29014', 1, 1, 46929),
#  ('SoRu39229', 4, 4, 15301),
#  ('KiRu29503', 9, 9, 26847),
#  ('SoRu36266', 2, 2, 12970),
#  ('AkRu05361', 0, 0, 47792),
#  ('KiMr25160', 2, 2, 44449),
#  ('HaRu20437', 3, 3, 20320),
#  ('AkRu07633', 2, 2, 1559),
#  ('KiZu31150', 3, 3, 20774),
#  ('AmDa11554', 5, 5, 5399),
#  ('KiRu26928', 2, 2, 13253),
#  ('AmPw12323', 0, 0, 10555),
#  ('KiHa23217', 2, 2, 48621),
#  ('SoRu37942', 1, 1, 38213),
#  ('KiHa22705', 3, 3, 47252),
#  ('AmAs10704', 9, 9, 48994),
#  ('HaRu20407', 2, 2, 35401),
#  ('AmRu15051', 7, 7, 16183),
#  ('KiRu30027', 1, 1, 49554),
#  ('HaRu18920', 1, 1, 9095),
#  ('AkRu06193', 3, 3, 39372),
#  ('AmRu13603', 3, 3, 44026),
#  ('AkRu05736', 3, 3, 17104),
#  ('AkRu05049', 3, 3, 40370),
#  ('SoRu36495', 1, 1, 34707),
#  ('KiIs24165', 2, 2, 35498),
#  ('KiHa22801', 1, 1, 5622),
#  ('KiRu30402', 1, 1, 17414),
#  ('AkRu07212', 3, 3, 46074),
#  ('SoMa33737', 2, 2, 29470),
#  ('AkRu05996', 1, 1, 46018),
#  ('SoRu37485', 1, 1, 27125),
#  ('HaRu18692', 3, 3, 49673),
#  ('AmDa12115', 1, 1, 42224),
#  ('SoBa31675', 9, 9, 16460),
#  ('KiRu27091', 3, 3, 26538),
#  ('SoIl32343', 6, 6, 25624),
#  ('AkRu06469', 3, 3, 42900),
#  ('AkRu02879', 3, 3, 33923),
#  ('HaSe21180', 1, 1, 17974),
#  ('AkRu04129', 3, 3, 51500),
#  ('AkRu03049', 3, 3, 22872),
#  ('KiRu26019', 2, 2, 17023),
#  ('AkRu05567', 2, 2, 8587),
#  ('AmRu13392', 9, 9, 32140),
#  ('KiRu29277', 6, 6, 24109),
#  ('KiHa22725', 1, 1, 25905),
#  ('AkRu07750', 3, 3, 54228),
#  ('HaRu18221', 2, 2, 32744),
#  ('AkRu03866', 3, 3, 49123),
#  ('AmAm09904', 9, 9, 32466),
#  ('AkRu05381', 6, 6, 39185),
#  ('SoRu36309', 0, 0, 42077),
#  ('SoIl32516', 2, 2, 43248),
#  ('SoRu38501', 7, 7, 30475),
#  ('KiMr24550', 9, 9, 37696),
#  ('KiRu25794', 3, 3, 46016),
#  ('KiRu29013', 2, 2, 11978),
#  ('SoRu34827', 0, 0, 40645),
#  ('KiAm22034', 9, 9, 5817),
#  ('AmRu13070', 3, 3, 23813),
#  ('AkRu05973', 3, 3, 34),
#  ('AkRu08930', 2, 2, 37498),
#  ('AkRu05986', 3, 3, 46842),
#  ('SoRu38405', 0, 0, 22416),
#  ('KiRu25582', 3, 3, 37012),
#  ('KiMr24938', 3, 3, 56452),
#  ('KiRu27187', 2, 2, 26610),
#  ('KiRu29008', 2, 2, 49777),
#  ('AkRu06851', 3, 3, 21258),
#  ('AmRu14096', 9, 9, 15377),
#  ('HaDe16498', 1, 1, 5323),
#  ('AmRu15671', 0, 0, 52854),
#  ('AkRu02917', 7, 7, 7009),
#  ('AkRu08658', 0, 0, 57517),
#  ('KiHa23098', 9, 9, 52912),
#  ('KiRu27709', 2, 2, 21262),
#  ('SoKo33173', 3, 3, 56705),
#  ('KiRu29070', 1, 1, 15857),
#  ('KiRu26448', 3, 3, 42776),
#  ('AkRu02702', 4, 4, 2355),
#  ('AmBe11096', 9, 9, 32963),
#  ('AmAm09974', 9, 9, 16439),
#  ('AmAb09303', 0, 0, 13759),
#  ('AmRu13533', 2, 2, 57922),
#  ('HaRu17490', 6, 6, 2632),
#  ('AkKi01435', 1, 1, 41480),
#  ('HaRu17778', 0, 0, 29146),
#  ('KiIs23983', 1, 1, 56912),
#  ('AkRu02837', 2, 2, 28621),
#  ('SoRu34768', 0, 0, 10051),
#  ('AkRu05737', 2, 2, 15456),
#  ('SoIl32905', 9, 9, 41114),
#  ('AkRu04984', 2, 2, 13896),
#  ('HaZa21724', 3, 3, 15203),
#  ('KiRu30412', 9, 9, 5159),
#  ('HaRu17357', 9, 9, 45446),
#  ('AkRu04085', 0, 0, 38287),
#  ('AkRu05064', 0, 0, 32836),
#  ('KiRu29350', 3, 3, 12862),
#  ('SoCh32134', 9, 9, 55066),
#  ('SoRu36758', 6, 6, 33597),
#  ('SoRu37498', 3, 3, 19229),
#  ('AmAs10873', 2, 2, 14096),
#  ('AkLu02515', 3, 3, 5276),
#  ('AkHa00168', 9, 9, 56724),
#  ('KiZu31241', 3, 3, 25547),
#  ('AkRu07740', 2, 2, 1795),
#  ('HaRu17286', 2, 2, 54217),
#  ('AmAs10647', 7, 7, 37490),
#  ('AkRu04500', 1, 1, 57194),
#  ('SoMa34599', 0, 0, 59292),
#  ('AkRu07105', 2, 2, 57128),
#  ('AkKi01263', 2, 2, 24824),
#  ('SoBa31813', 3, 3, 41818),
#  ('AmRu12815', 2, 2, 29336),
#  ('AmRu15123', 9, 9, 38834),
#  ('KiHa23019', 1, 1, 23817),
#  ('SoRu36901', 5, 5, 10831),
#  ('KiRu26810', 3, 3, 49077),
#  ('KiRu26021', 1, 1, 11340),
#  ('SoRu39268', 9, 9, 36539),
#  ('HaRu20314', 0, 0, 57200),
#  ('HaRu20313', 5, 5, 27142),
#  ('AkRu06089', 2, 2, 55127),
#  ('SoRu37335', 2, 2, 633),
#  ('KiRu27373', 2, 2, 36397),
#  ('SoBa31528', 3, 3, 38805),
#  ('HaRu18118', 9, 9, 51917),
#  ('AkLu01669', 2, 2, 47128),
#  ('HaRu18412', 2, 2, 31599),
#  ('AmAm09510', 9, 9, 56856),
#  ('AkRu07097', 2, 2, 34827),
#  ('AmAm09372', 9, 9, 298),
#  ('SoIl32874', 3, 3, 8440),
#  ('HaRu19673', 6, 6, 16129),
#  ('KiRu28996', 7, 7, 42678),
#  ('SoRu36863', 0, 0, 41463),
#  ('SoRu39448', 1, 1, 35190),
#  ('SoRu36213', 0, 0, 14459),
#  ('SoRu36690', 9, 9, 49181),
#  ('AkRu06613', 2, 2, 37358),
#  ('KiRu25841', 1, 1, 10850),
#  ('AkRu06609', 3, 3, 59265),
#  ('AkRu07303', 0, 0, 34005),
#  ('AmRu13360', 9, 9, 10094),
#  ('AkHa00401', 1, 1, 22192),
#  ('HaRu19396', 1, 1, 34478),
#  ('KiRu28031', 0, 0, 42882),
#  ('AkRu06402', 0, 0, 6007),
#  ('AkRu05968', 1, 1, 45848),
#  ('AkRu04504', 7, 7, 37486),
#  ('AmRu13823', 9, 9, 46280),
#  ('SoCh32233', 0, 0, 21902),
#  ('KiZu30714', 3, 3, 3463),
#  ('SoRu37892', 0, 0, 53500),
#  ('AkRu04522', 5, 5, 1188),
#  ('AkRu03221', 1, 1, 25918),
#  ('KiRu29454', 3, 3, 3315),
#  ('AmAs10708', 9, 9, 9829),
#  ('SoBa31719', 1, 1, 27964),
#  ('HaSe21173', 3, 3, 47919),
#  ('SoBa31681', 1, 1, 42008),
#  ('AkRu03515', 9, 9, 8377),
#  ('KiRu26004', 3, 3, 24350),
#  ('SoIl32610', 9, 9, 27990),
#  ('KiMr24590', 2, 2, 7912),
#  ('AmRu15533', 3, 3, 31401),
#  ('AmRu14792', 4, 4, 30408),
#  ('KiIs23570', 2, 2, 52505),
#  ('KiRu28181', 1, 1, 50024),
#  ('AkRu04779', 0, 0, 49061),
#  ('HaDj16730', 1, 1, 20804),
#  ('SoRu36270', 0, 0, 4106),
#  ('AkLu01920', 9, 9, 58262),
#  ('HaSe21058', 3, 3, 22885),
#  ('KiRu27251', 3, 3, 44884),
#  ('HaRu18859', 7, 7, 1780),
#  ('SoBa31693', 2, 2, 56150),
#  ('AmRu15846', 2, 2, 23530),
#  ('AkRu07599', 7, 7, 49442),
#  ('SoIl32539', 2, 2, 54753),
#  ('KiIs24129', 1, 1, 43208),
#  ('KiRu29410', 5, 5, 32684),
#  ('AmRu13398', 2, 2, 6901),
#  ('AmRu14768', 9, 9, 33709),
#  ('HaZa21689', 1, 1, 12588),
#  ('KiMr24607', 2, 2, 29132),
#  ('AkLu02190', 4, 4, 17701),
#  ('KiHa23086', 3, 3, 44263),
#  ('SoRu37253', 4, 4, 16962),
#  ('AkRu06420', 3, 3, 26189),
#  ('KiIs23885', 1, 1, 37283),
#  ('SoRu35094', 9, 9, 54955),
#  ('AkRu05925', 4, 4, 47667),
#  ('KiRu26556', 2, 2, 16291),
#  ('KiRu26696', 1, 1, 42391),
#  ('AmRu14615', 3, 3, 47908),
#  ('AkRu04588', 6, 6, 8775),
#  ('SoRu34723', 4, 4, 20755),
#  ('AkRu05407', 9, 9, 12942),
#  ('KiRu26564', 9, 9, 19718),
#  ('AmRu14446', 9, 9, 46802),
#  ('HaZa21660', 1, 1, 40356),
#  ('KiRu26247', 3, 3, 3538),
#  ('AmRu13777', 9, 9, 41594),
#  ('KiRu27156', 9, 9, 11298),
#  ('HaRu19549', 1, 1, 21864),
#  ('KiHa23378', 2, 2, 25316),
#  ('AkKi01484', 3, 3, 36270),
#  ('AmPw12289', 9, 9, 32911),
#  ('KiZu30761', 4, 4, 22846),
#  ('AkRu07396', 2, 2, 26265),
#  ('KiMr25130', 2, 2, 22323),
#  ('AmRu13981', 3, 3, 34194),
#  ('AkRu03712', 3, 3, 41661),
#  ('HaRu20772', 1, 1, 51372),
#  ('SoRu39481', 9, 9, 50054),
#  ('SoIl32694', 9, 9, 35531),
#  ('AmPw12413', 5, 5, 59790),
#  ('AmDa11919', 3, 3, 14447),
#  ('AkRu03027', 3, 3, 30389),
#  ('AkHa00632', 3, 3, 37406),
#  ('KiAm22274', 2, 2, 32826),
#  ('AmAm09592', 9, 9, 36031),
#  ('AmPw12766', 3, 3, 7637),
#  ('AmRu15057', 2, 2, 9824),
#  ('HaSe21006', 3, 3, 17359),
#  ('SoRu37970', 2, 2, 5339),
#  ('AkRu08552', 3, 3, 23771),
#  ('SoRu36209', 1, 1, 29816),
#  ('AkRu03630', 7, 7, 7164),
#  ('HaRu17764', 0, 0, 5406),
#  ('SoRu37008', 3, 3, 14413),
#  ('AmAm09794', 2, 2, 29311),
#  ('KiRu29794', 3, 3, 52882),
#  ('HaDe16581', 1, 1, 29443),
#  ('KiRu26207', 9, 9, 51526),
#  ('KiAm22626', 1, 1, 45247),
#  ('AmRu15704', 2, 2, 9734),
#  ('SoRu36586', 1, 1, 59814),
#  ('AkHa00779', 3, 3, 48362),
#  ('SoRu34876', 3, 3, 48856),
#  ('KiHa23010', 1, 1, 29077),
#  ('SoBa31739', 3, 3, 24269),
#  ('SoRu37471', 9, 9, 28053),
#  ('HaRu20392', 4, 4, 16966),
#  ('KiRu27220', 3, 3, 694),
#  ('AkRu03641', 2, 2, 46320),
#  ('AkRu05864', 3, 3, 20781),
#  ('KiMr24512', 1, 1, 43236),
#  ('AkRu06015', 2, 2, 14819),
#  ('HaDe16405', 1, 1, 26090),
#  ('SoRu34678', 2, 2, 3454),
#  ('SoRu35092', 0, 0, 24825),
#  ('AkRu04237', 3, 3, 5770),
#  ('SoRu36345', 3, 3, 32080),
#  ('SoRu34954', 6, 6, 29970),
#  ('AkRu05338', 1, 1, 34361),
#  ('KiHa23446', 9, 9, 35358),
#  ('KiHa22779', 2, 2, 27371),
#  ('SoKo33339', 3, 3, 47390),
#  ('SoRu36597', 1, 1, 14521),
#  ('HaRu18505', 2, 2, 12721),
#  ('AmPw12411', 9, 9, 29683),
#  ('SoCh32036', 9, 9, 34365),
#  ('SoRu38172', 0, 0, 4139),
#  ('AmRu15053', 9, 9, 28334),
#  ('AkRu05095', 2, 2, 58184),
#  ('AmPw12305', 9, 9, 59743),
#  ('AkRu04599', 9, 9, 3681),
#  ('SoRu37925', 3, 3, 50505),
#  ('AkRu03951', 2, 2, 33059),
#  ('AkRu08194', 5, 5, 40688),
#  ('KiRu26177', 2, 2, 41921),
#  ('KiRu25895', 1, 1, 26218),
#  ('SoRu37119', 9, 9, 28974),
#  ('SoKo33426', 1, 1, 59649),
#  ('KiRu25386', 2, 2, 6479),
#  ('AkHa00694', 9, 9, 17576),
#  ('AmRu13271', 9, 9, 51450),
#  ('AkRu05601', 1, 1, 27835),
#  ('AkRu08142', 1, 1, 22347),
#  ('SoIl32529', 2, 2, 22580),
#  ('AkRu05172', 6, 6, 33282),
#  ('AmRu13829', 9, 9, 22369),
#  ('KiIs23562', 1, 1, 7108),
#  ('KiRu30676', 2, 2, 38161),
#  ('SoRu37941', 9, 9, 35329),
#  ('AkRu04619', 3, 3, 45192),
#  ('KiRu29170', 9, 9, 28644),
#  ('HaYa21619', 2, 2, 17466),
#  ('AkRu06874', 4, 4, 51120),
#  ('SoRu38873', 0, 0, 31671),
#  ('KiIs23489', 9, 9, 48180),
#  ('HaRu19495', 3, 3, 55013),
#  ('KiRu30328', 0, 0, 52107),
#  ('HaAm16281', 2, 2, 53541),
#  ('KiAm22340', 2, 2, 55804),
#  ('KiRu28260', 1, 1, 14540),
#  ('SoRu38872', 0, 0, 50159),
#  ...]

# %% [markdown]
# Once we've filtered out the duplicate records, we now have a clear view of **1518** surveyor records that match those of the auditor. We can calculate the approximate percentage of accurate scores recorded by the surveyors per the auditor's report.

# %%
print(f"Approximately  {round((1518/1620)*100)} % of Surveyoy's records match those of the Auditor")
# Out:
# Approximately  94 % of Surveyoy's records match those of the Auditor

# %% [markdown]
# We now know that a huge percentage of the surveyors scores were accurate, what of the remaining ~6%? Let's have a look at those.

# %% [markdown]
# ## Investigating Difference Patterns in Auditor & Surveyor Scores
#
# We filter the resulting dataset to display records where the `auditor_score` differs from the `surveyor_score`. In our previous analysis, we did not focus on water quality scores but instead investigated various types of water sources.
#
# To expand our analysis, let’s also include the `type_of_water_source` attribute from the `water_source` entity by **joining** it to our dataset on the `source_id` attribute. This will help ensure there are no discrepancies related to water source classification.
# .

# %%
# %%sql
# SELECT
#     a.location_id AS auditor_report,
#     a.true_water_source_score AS auditor_score,
#     q.subjective_quality_score AS surveyor_score,
#     v.record_id,
#     s.type_of_water_source AS surveyor_source
#
# FROM
#     auditor_report AS a
# JOIN
#     visits AS v
#     ON a.location_id = v.location_id
# JOIN
#     water_quality AS q
#     ON v.record_id = q.record_id
# JOIN
#     water_source AS s
#     ON s.source_id = v.source_id
# WHERE
#     a.true_water_source_score != q.subjective_quality_score
# AND
#     v.visit_count = 1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 3, 10, 21160, 'well'),
#  ('KiRu29290', 3, 10, 7938, 'shared_tap'),
#  ('KiHa22748', 9, 10, 43140, 'tap_in_home_broken'),
#  ('SoRu37841', 6, 10, 18495, 'shared_tap'),
#  ('KiRu27884', 1, 10, 33931, 'well'),
#  ('KiZu31170', 9, 10, 17950, 'tap_in_home_broken'),
#  ('KiZu31370', 3, 10, 36864, 'shared_tap'),
#  ('AkRu06495', 2, 10, 45924, 'well'),
#  ('HaRu17528', 1, 10, 30524, 'well'),
#  ('SoRu38331', 3, 10, 13192, 'shared_tap'),
#  ('AmRu15556', 9, 10, 15461, 'tap_in_home_broken'),
#  ('AmAm09607', 9, 10, 55067, 'tap_in_home_broken'),
#  ('AkHa00314', 9, 10, 29407, 'tap_in_home_broken'),
#  ('KiRu26598', 9, 10, 28874, 'tap_in_home_broken'),
#  ('KiIs23853', 2, 10, 55796, 'well'),
#  ('AkRu03475', 1, 10, 33630, 'well'),
#  ('KiIs24083', 2, 10, 28404, 'well'),
#  ('AmAm09631', 9, 10, 14211, 'tap_in_home_broken'),
#  ('KiRu30343', 2, 10, 51075, 'well'),
#  ('AmRu13668', 9, 10, 10586, 'tap_in_home_broken'),
#  ('SoBa31691', 0, 10, 3267, 'river'),
#  ('AkRu04116', 3, 10, 53182, 'well'),
#  ('AmPw12272', 9, 10, 50239, 'tap_in_home_broken'),
#  ('SoRu37524', 3, 10, 59640, 'well'),
#  ('AmRu14691', 2, 10, 40443, 'well'),
#  ('KiRu29556', 2, 10, 5645, 'well'),
#  ('KiZu30847', 9, 10, 57038, 'tap_in_home_broken'),
#  ('AkHa00363', 0, 10, 25387, 'river'),
#  ('SoBa31761', 2, 10, 3296, 'well'),
#  ('SoKo33094', 0, 10, 16159, 'river'),
#  ('HaSe21323', 3, 10, 26260, 'well'),
#  ('AmDa11466', 1, 10, 17086, 'well'),
#  ('HaRu17038', 2, 10, 7867, 'well'),
#  ('KiRu27364', 0, 10, 38102, 'river'),
#  ('AkRu05880', 7, 10, 12705, 'shared_tap'),
#  ('KiRu29696', 2, 10, 251, 'well'),
#  ('KiRu27065', 0, 10, 29772, 'river'),
#  ('AkRu07426', 3, 10, 50918, 'shared_tap'),
#  ('AmAs10124', 6, 10, 3154, 'shared_tap'),
#  ('HaRu18142', 2, 10, 32555, 'well'),
#  ('AkRu06284', 3, 10, 32008, 'shared_tap'),
#  ('KiRu25347', 2, 10, 54560, 'well'),
#  ('AmRu14364', 2, 10, 42302, 'well'),
#  ('KiZu31100', 3, 10, 31033, 'shared_tap'),
#  ('KiRu29537', 2, 10, 15869, 'well'),
#  ('AkRu03973', 3, 10, 49033, 'well'),
#  ('SoKo33333', 2, 10, 56898, 'well'),
#  ('KiRu26688', 2, 10, 55794, 'well'),
#  ('SoIl32575', 1, 10, 3116, 'well'),
#  ('SoMa34366', 9, 10, 26183, 'tap_in_home_broken'),
#  ('AkRu04935', 3, 10, 16410, 'shared_tap'),
#  ('HaRu19244', 2, 10, 25725, 'well'),
#  ('SoRu36708', 3, 10, 7252, 'shared_tap'),
#  ('AkRu04508', 1, 10, 37357, 'well'),
#  ('AkRu03848', 3, 10, 43412, 'shared_tap'),
#  ('AkLu02500', 3, 10, 24797, 'well'),
#  ('AkRu07310', 9, 10, 37457, 'tap_in_home_broken'),
#  ('AkKi01267', 9, 10, 58866, 'tap_in_home_broken'),
#  ('AmRu14245', 9, 10, 47227, 'tap_in_home_broken'),
#  ('KiZu30932', 9, 10, 49082, 'tap_in_home_broken'),
#  ('KiAm22092', 9, 10, 8186, 'tap_in_home_broken'),
#  ('KiRu29147', 0, 10, 3179, 'river'),
#  ('SoRu38045', 9, 10, 26566, 'tap_in_home_broken'),
#  ('SoIl32770', 0, 10, 7548, 'river'),
#  ('HaDj16824', 1, 10, 52429, 'well'),
#  ('KiRu29639', 1, 10, 45008, 'well'),
#  ('KiRu29329', 0, 10, 11962, 'river'),
#  ('AkHa00311', 9, 10, 21392, 'tap_in_home_broken'),
#  ('KiMr24919', 1, 10, 23328, 'well'),
#  ('HaRu20005', 1, 10, 23715, 'well'),
#  ('AmRu14113', 2, 10, 3841, 'well'),
#  ('AkKi01256', 1, 10, 34833, 'well'),
#  ('SoRu36101', 3, 10, 3351, 'shared_tap'),
#  ('SoRu39544', 0, 10, 17929, 'river'),
#  ('AkHa00053', 9, 10, 28869, 'tap_in_home_broken'),
#  ('HaSe20888', 9, 10, 57001, 'tap_in_home_broken'),
#  ('SoRu38401', 2, 10, 20163, 'well'),
#  ('AmRu14223', 1, 10, 23126, 'well'),
#  ('AmRu14887', 9, 10, 31028, 'tap_in_home_broken'),
#  ('AkRu02789', 2, 10, 49443, 'well'),
#  ('HaRu20146', 2, 10, 36818, 'well'),
#  ('AkRu05741', 3, 10, 19961, 'well'),
#  ('KiMr24359', 2, 10, 18443, 'well'),
#  ('AkKi00847', 3, 10, 5889, 'well'),
#  ('HaRu19621', 3, 10, 55949, 'shared_tap'),
#  ('HaYa21395', 2, 10, 28729, 'well'),
#  ('AkRu03245', 2, 10, 3233, 'well'),
#  ('HaRu20544', 1, 10, 33833, 'well'),
#  ('AmRu14959', 9, 10, 1556, 'tap_in_home_broken'),
#  ('KiRu30640', 2, 10, 47474, 'well'),
#  ('SoMa34211', 1, 10, 24867, 'well'),
#  ('SoRu38535', 0, 10, 44282, 'river'),
#  ('SoRu36566', 3, 10, 11097, 'shared_tap'),
#  ('AmAs10336', 3, 10, 293, 'shared_tap'),
#  ('AmRu15719', 9, 10, 34822, 'tap_in_home_broken'),
#  ('AkRu08640', 3, 10, 39250, 'shared_tap'),
#  ('AmRu13226', 9, 10, 55271, 'tap_in_home_broken'),
#  ('AmPw12480', 5, 10, 47831, 'shared_tap'),
#  ('AmRu14842', 2, 10, 47055, 'well'),
#  ('AkRu03358', 1, 10, 31888, 'well'),
#  ('AmRu13433', 9, 10, 57735, 'tap_in_home_broken'),
#  ('AmAm09956', 1, 10, 15929, 'well')]

# %% [markdown]
# As we can see from the resulting dataset, there is a total of **102** records. We can also see that there are no differences between they types of water sources from the auditor report and the surveyors records being compared, so we are safe to proceed with our investigation on that account. Moving forward, the SQL query we created will definitely get more complex so let's see how we can make our lives easier by using **Common Table Expressions (CTEs)**. To do this, we wrap the query we have in a **CTE** and name the expression as `Incorrect_records`. This allows us to break our query down into simpler & more digestable steps. It also enables us to use the referenced query as if it was a table.
# **
# NOTE: CT**Es are not actual tables hence, they d**o N**OT store data.
#
# While we're on it, let us add `the empl`oyee entity **and **JOIN it to our resulting dataset on `the assigned_employe`e_id attribute so we can have a first look at the surveyors who recorded inaccurate scores per the auditor's report.

# %%
# %%sql
# # Create a CTE of employees/surveyors responsible for the errornours scores
# WITH Incorrect_records AS (
#     SELECT
#         auditor_report.location_id AS audit_location,
#         visits.record_id,
#         employee.employee_name,
#         auditor_report.true_water_source_score AS auditor_score,
#         water_quality.subjective_quality_score AS surveyor_score
#     FROM
#         md_water_services.auditor_report
#     JOIN
#         md_water_services.visits
#         ON visits.location_id = auditor_report.location_id
#     JOIN
#         md_water_services.water_quality
#         ON visits.record_id = water_quality.record_id
#     JOIN
#         md_water_services.employee
#         ON visits.assigned_employee_id = employee.assigned_employee_id
#     WHERE
#         visits.visit_count = 1
#         AND auditor_report.true_water_source_score != water_quality.subjective_quality_score
# )
# SELECT *
# FROM Incorrect_records;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 'Rudo Imani', 3, 10),
#  ('KiRu29290', 7938, 'Bello Azibo', 3, 10),
#  ('KiHa22748', 43140, 'Bello Azibo', 9, 10),
#  ('SoRu37841', 18495, 'Rudo Imani', 6, 10),
#  ('KiRu27884', 33931, 'Bello Azibo', 1, 10),
#  ('KiZu31170', 17950, 'Zuriel Matembo', 9, 10),
#  ('KiZu31370', 36864, 'Yewande Ebele', 3, 10),
#  ('AkRu06495', 45924, 'Bello Azibo', 2, 10),
#  ('HaRu17528', 30524, 'Jengo Tumaini', 1, 10),
#  ('SoRu38331', 13192, 'Zuriel Matembo', 3, 10),
#  ('AmRu15556', 15461, 'Farai Nia', 9, 10),
#  ('AmAm09607', 55067, 'Malachi Mavuso', 9, 10),
#  ('AkHa00314', 29407, 'Zuriel Matembo', 9, 10),
#  ('KiRu26598', 28874, 'Malachi Mavuso', 9, 10),
#  ('KiIs23853', 55796, 'Bello Azibo', 2, 10),
#  ('AkRu03475', 33630, 'Makena Thabo', 1, 10),
#  ('KiIs24083', 28404, 'Lalitha Kaburi', 2, 10),
#  ('AmAm09631', 14211, 'Malachi Mavuso', 9, 10),
#  ('KiRu30343', 51075, 'Zuriel Matembo', 2, 10),
#  ('AmRu13668', 10586, 'Gamba Shani', 9, 10),
#  ('SoBa31691', 3267, 'Jengo Tumaini', 0, 10),
#  ('AkRu04116', 53182, 'Malachi Mavuso', 3, 10),
#  ('AmPw12272', 50239, 'Malachi Mavuso', 9, 10),
#  ('SoRu37524', 59640, 'Enitan Zuri', 3, 10),
#  ('AmRu14691', 40443, 'Bello Azibo', 2, 10),
#  ('KiRu29556', 5645, 'Bello Azibo', 2, 10),
#  ('KiZu30847', 57038, 'Bello Azibo', 9, 10),
#  ('AkHa00363', 25387, 'Bello Azibo', 0, 10),
#  ('SoBa31761', 3296, 'Makena Thabo', 2, 10),
#  ('SoKo33094', 16159, 'Lalitha Kaburi', 0, 10),
#  ('HaSe21323', 26260, 'Bello Azibo', 3, 10),
#  ('AmDa11466', 17086, 'Malachi Mavuso', 1, 10),
#  ('HaRu17038', 7867, 'Jengo Tumaini', 2, 10),
#  ('KiRu27364', 38102, 'Zuriel Matembo', 0, 10),
#  ('AkRu05880', 12705, 'Zuriel Matembo', 7, 10),
#  ('KiRu29696', 251, 'Bello Azibo', 2, 10),
#  ('KiRu27065', 29772, 'Bello Azibo', 0, 10),
#  ('AkRu07426', 50918, 'Rudo Imani', 3, 10),
#  ('AmAs10124', 3154, 'Farai Nia', 6, 10),
#  ('HaRu18142', 32555, 'Thandiwe Kito', 2, 10),
#  ('AkRu06284', 32008, 'Rudo Imani', 3, 10),
#  ('KiRu25347', 54560, 'Malachi Mavuso', 2, 10),
#  ('AmRu14364', 42302, 'Bello Azibo', 2, 10),
#  ('KiZu31100', 31033, 'Bello Azibo', 3, 10),
#  ('KiRu29537', 15869, 'Makena Thabo', 2, 10),
#  ('AkRu03973', 49033, 'Zuriel Matembo', 3, 10),
#  ('SoKo33333', 56898, 'Bello Azibo', 2, 10),
#  ('KiRu26688', 55794, 'Rudo Imani', 2, 10),
#  ('SoIl32575', 3116, 'Zuriel Matembo', 1, 10),
#  ('SoMa34366', 26183, 'Zuriel Matembo', 9, 10),
#  ('AkRu04935', 16410, 'Lalitha Kaburi', 3, 10),
#  ('HaRu19244', 25725, 'Zuriel Matembo', 2, 10),
#  ('SoRu36708', 7252, 'Bello Azibo', 3, 10),
#  ('AkRu04508', 37357, 'Bello Azibo', 1, 10),
#  ('AkRu03848', 43412, 'Bello Azibo', 3, 10),
#  ('AkLu02500', 24797, 'Bello Azibo', 3, 10),
#  ('AkRu07310', 37457, 'Lalitha Kaburi', 9, 10),
#  ('AkKi01267', 58866, 'Enitan Zuri', 9, 10),
#  ('AmRu14245', 47227, 'Zuriel Matembo', 9, 10),
#  ('KiZu30932', 49082, 'Malachi Mavuso', 9, 10),
#  ('KiAm22092', 8186, 'Bello Azibo', 9, 10),
#  ('KiRu29147', 3179, 'Malachi Mavuso', 0, 10),
#  ('SoRu38045', 26566, 'Pili Zola', 9, 10),
#  ('SoIl32770', 7548, 'Lalitha Kaburi', 0, 10),
#  ('HaDj16824', 52429, 'Enitan Zuri', 1, 10),
#  ('KiRu29639', 45008, 'Bello Azibo', 1, 10),
#  ('KiRu29329', 11962, 'Lalitha Kaburi', 0, 10),
#  ('AkHa00311', 21392, 'Usafi Ayo', 9, 10),
#  ('KiMr24919', 23328, 'Bello Azibo', 1, 10),
#  ('HaRu20005', 23715, 'Malachi Mavuso', 1, 10),
#  ('AmRu14113', 3841, 'Yewande Ebele', 2, 10),
#  ('AkKi01256', 34833, 'Farai Nia', 1, 10),
#  ('SoRu36101', 3351, 'Enitan Zuri', 3, 10),
#  ('SoRu39544', 17929, 'Gamba Shani', 0, 10),
#  ('AkHa00053', 28869, 'Malachi Mavuso', 9, 10),
#  ('HaSe20888', 57001, 'Zuriel Matembo', 9, 10),
#  ('SoRu38401', 20163, 'Zuriel Matembo', 2, 10),
#  ('AmRu14223', 23126, 'Deka Osumare', 1, 10),
#  ('AmRu14887', 31028, 'Bello Azibo', 9, 10),
#  ('AkRu02789', 49443, 'Farai Nia', 2, 10),
#  ('HaRu20146', 36818, 'Zuriel Matembo', 2, 10),
#  ('AkRu05741', 19961, 'Bello Azibo', 3, 10),
#  ('KiMr24359', 18443, 'Ona Sefu', 2, 10),
#  ('AkKi00847', 5889, 'Zuriel Matembo', 3, 10),
#  ('HaRu19621', 55949, 'Yewande Ebele', 3, 10),
#  ('HaYa21395', 28729, 'Bello Azibo', 2, 10),
#  ('AkRu03245', 3233, 'Malachi Mavuso', 2, 10),
#  ('HaRu20544', 33833, 'Lalitha Kaburi', 1, 10),
#  ('AmRu14959', 1556, 'Gamba Shani', 9, 10),
#  ('KiRu30640', 47474, 'Malachi Mavuso', 2, 10),
#  ('SoMa34211', 24867, 'Malachi Mavuso', 1, 10),
#  ('SoRu38535', 44282, 'Zuriel Matembo', 0, 10),
#  ('SoRu36566', 11097, 'Malachi Mavuso', 3, 10),
#  ('AmAs10336', 293, 'Xola Uzuri', 3, 10),
#  ('AmRu15719', 34822, 'Malachi Mavuso', 9, 10),
#  ('AkRu08640', 39250, 'Malachi Mavuso', 3, 10),
#  ('AmRu13226', 55271, 'Malachi Mavuso', 9, 10),
#  ('AmPw12480', 47831, 'Zuriel Matembo', 5, 10),
#  ('AmRu14842', 47055, 'Bello Azibo', 2, 10),
#  ('AkRu03358', 31888, 'Malachi Mavuso', 1, 10),
#  ('AmRu13433', 57735, 'Malachi Mavuso', 9, 10),
#  ('AmAm09956', 15929, 'Malachi Mavuso', 1, 10)]

# %% [markdown]
# Our `Incorrect_records` **CTE works**, we notice from the output above that some surveyor names repeat themselves across the records which means that some surveyors messed up more than once. First let's take a look at the unique number of surveyors that recorded inaccurate scores.

# %%
# %%sql
# # Get the number of surveyors responsible for the errornous data
# WITH Incorrect_records AS (
#     SELECT
#         auditor_report.location_id AS audit_location,
#         visits.record_id,
#         employee.employee_name,
#         auditor_report.true_water_source_score AS auditor_score,
#         water_quality.subjective_quality_score AS surveyor_score
#     FROM
#         md_water_services.auditor_report
#     JOIN
#         md_water_services.visits
#         ON visits.location_id = auditor_report.location_id
#     JOIN
#         md_water_services.water_quality
#         ON visits.record_id = water_quality.record_id
#     JOIN
#         md_water_services.employee
#         ON visits.assigned_employee_id = employee.assigned_employee_id
#     WHERE
#         visits.visit_count = 1
#         AND auditor_report.true_water_source_score != water_quality.subjective_quality_score
# )
# SELECT DISTINCT employee_name
# FROM Incorrect_records;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 17 rows affected.
# [('Rudo Imani',),
#  ('Bello Azibo',),
#  ('Zuriel Matembo',),
#  ('Yewande Ebele',),
#  ('Jengo Tumaini',),
#  ('Farai Nia',),
#  ('Malachi Mavuso',),
#  ('Makena Thabo',),
#  ('Lalitha Kaburi',),
#  ('Gamba Shani',),
#  ('Enitan Zuri',),
#  ('Thandiwe Kito',),
#  ('Pili Zola',),
#  ('Usafi Ayo',),
#  ('Deka Osumare',),
#  ('Ona Sefu',),
#  ('Xola Uzuri',)]

# %% [markdown]
# **17** Surveyors have errornous records from the output above. We take our analysis further by aggregating the number of times each surveyor recorded inaccurate scores using the `COUNT` function and grouping the results by `employee_name` attribute.

# %%
# %%sql
# # Count the number of times the employees/surveyors responsible for errornous scores made mistakes
# WITH Incorrect_records AS (
#     SELECT
#         auditor_report.location_id AS audit_location,
#         visits.record_id,
#         employee.employee_name,
#         auditor_report.true_water_source_score AS auditor_score,
#         water_quality.subjective_quality_score AS surveyor_score
#     FROM
#         md_water_services.auditor_report
#     JOIN
#         md_water_services.visits
#         ON visits.location_id = auditor_report.location_id
#     JOIN
#         md_water_services.water_quality
#         ON visits.record_id = water_quality.record_id
#     JOIN
#         md_water_services.employee
#         ON visits.assigned_employee_id = employee.assigned_employee_id
#     WHERE
#         visits.visit_count = 1
#         AND auditor_report.true_water_source_score != water_quality.subjective_quality_score
# )
# SELECT
#     employee_name,
#     COUNT(employee_name) AS number_of_mistakes
# FROM
#     Incorrect_records
# GROUP BY
#     employee_name
# ORDER BY number_of_mistakes DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 17 rows affected.
# [('Bello Azibo', 26),
#  ('Malachi Mavuso', 21),
#  ('Zuriel Matembo', 17),
#  ('Lalitha Kaburi', 7),
#  ('Rudo Imani', 5),
#  ('Farai Nia', 4),
#  ('Enitan Zuri', 4),
#  ('Yewande Ebele', 3),
#  ('Jengo Tumaini', 3),
#  ('Makena Thabo', 3),
#  ('Gamba Shani', 3),
#  ('Thandiwe Kito', 1),
#  ('Pili Zola', 1),
#  ('Usafi Ayo', 1),
#  ('Deka Osumare', 1),
#  ('Ona Sefu', 1),
#  ('Xola Uzuri', 1)]

# %% [markdown]
# We can see that **Bello Azibo** had the highest number of mistakes at **26**, followed by **Malachi Mavuso** at **21**. This might be due to genuine errors or just plain old malice but we don’t know for sure. We need to do some more investigation to see the root cause of the erroneous input from our surveyors. To make our work even simpler, let’s transform the `Incorrect_records` **CTE** into an SQL VIEW and add statements: attribute from the `auditor_report` entity while we’re at it.
#
# **NOTE:** Only run the cell below once and then comment out the SQL query since, ideally, the view should be created once.
#
# > **NOTE:** When you restart the notebook and run it again, you will encounter an error since the VIEW already exists in the database by the second run.

# %%
# %%sql
# Change the Incorrect_records CTE to a SQL VIEW
# CREATE VIEW Incorrect_records AS (
#     SELECT
#         auditor_report.location_id AS audit_location,
#         visits.record_id,
#         employee.employee_name,
#         auditor_report.true_water_source_score AS auditor_score,
#         water_quality.subjective_quality_score AS surveyor_score,
#         auditor_report.statements AS statements
#     FROM
#         md_water_services.auditor_report
#     JOIN
#         md_water_services.visits
#         ON visits.location_id = auditor_report.location_id
#     JOIN
#         md_water_services.water_quality
#         ON visits.record_id = water_quality.record_id
#     JOIN
#         md_water_services.employee
#         ON visits.assigned_employee_id = employee.assigned_employee_id
#     WHERE 
#         visits.visit_count = 1 
#         AND auditor_report.true_water_source_score != water_quality.subjective_quality_score
# );

# %% [markdown]
# Once we've transformed the **CTE** into a **VIEW**, we can test it out to see if our view works as expected.

# %%
# %sql SELECT * FROM md_water_services.Incorrect_records;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 102 rows affected.
# [('AkRu05215', 21160, 'Rudo Imani', 10, 3, "Villagers admired the official's visit for its respectful interactions, hard work, and genuine concern."),
#  ('KiRu29290', 7938, 'Bello Azibo', 10, 3, 'A young artist sketches the faces in the queue, capturing the weariness of daily hours spent waiting for water.'),
#  ('KiHa22748', 43140, 'Bello Azibo', 10, 9, "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('SoRu37841', 18495, 'Rudo Imani', 10, 6, "The official's respectful and diligent presence was met with heartfelt appreciation, creating a sense of closeness with the villagers."),
#  ('KiRu27884', 33931, 'Bello Azibo', 10, 1, "A traditional healer's empathy turns to bitterness, knowing that corrupt practices harm her community."),
#  ('KiZu31170', 17950, 'Zuriel Matembo', 10, 9, 'A community leader stood with his people, expressing concern for the water quality and the time lost in queues.","'),
#  ('KiZu31370', 36864, 'Yewande Ebele', 10, 3, "With a keen understanding of urban challenges, the official's visit left a lasting impression of respect and commitment."),
#  ('AkRu06495', 45924, 'Bello Azibo', 10, 2, 'A healthcare worker in the queue expressed fears about water-borne diseases, her face etched with worry.","'),
#  ('HaRu17528', 30524, 'Jengo Tumaini', 10, 1, 'With humility and diligence, the official formed bonds with the villagers that felt like genuine family connections.'),
#  ('SoRu38331', 13192, 'Zuriel Matembo', 10, 3, 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('AmRu15556', 15461, 'Farai Nia', 10, 9, "The official's presence left a positive impact on the community, admired for their genuine concern and efforts to improve urban living."),
#  ('AmAm09607', 55067, 'Malachi Mavuso', 10, 9, 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('AkHa00314', 29407, 'Zuriel Matembo', 10, 9, "A street vendor's sales suffer from time spent waiting, her concern for the water's quality affecting her products."),
#  ('KiRu26598', 28874, 'Malachi Mavuso', 10, 9, "A teenager's dreams are tempered by reality, her future threatened by the corrupt practices she sees around her."),
#  ('KiIs23853', 55796, 'Bello Azibo', 10, 2, "Villagers' wary accounts of an official's arrogance and detachment from their concerns raised suspicions. The mention of cash changing hands further tainted their perception."),
#  ('AkRu03475', 33630, 'Makena Thabo', 10, 1, "Villagers spoke highly of the official's humility and dedication, underscoring their respectful approach and familial connection."),
#  ('KiIs24083', 28404, 'Lalitha Kaburi', 10, 2, "A fisherman's anger boils beneath the surface, his livelihood threatened by the corrupt who tamper with water."),
#  ('AmAm09631', 14211, 'Malachi Mavuso', 10, 9, 'An elderly man lamented the endless queue, recalling times when water was abundant and clean.","'),
#  ('KiRu30343', 51075, 'Zuriel Matembo', 10, 2, "A university student's studies suffer from hours in line, dreams clouded by the daily reality of dirty water."),
#  ('AmRu13668', 10586, 'Gamba Shani', 10, 9, "The official's visit left a lasting impact, characterized by their respectful approach and dedication to uplifting the community."),
#  ('SoBa31691', 3267, 'Jengo Tumaini', 10, 0, "Villagers were touched by the official's sincere concern and approachable demeanor, creating an atmosphere of unity and understanding."),
#  ('AkRu04116', 53182, 'Malachi Mavuso', 10, 3, "A student's ambition is fueled by the daily water struggle, his determination to overcome evident in the queue."),
#  ('AmPw12272', 50239, 'Malachi Mavuso', 10, 9, "A subsistence farmer's worry for his crops extends to the queue, the struggle for water a shared community burden."),
#  ('SoRu37524', 59640, 'Enitan Zuri', 10, 3, 'Villagers held the official in high esteem, praising their dedication, respect, and the familial connections they established.'),
#  ('AmRu14691', 40443, 'Bello Azibo', 10, 2, "An artisan's creative mind is stifled by the wait, thoughts of craft overshadowed by concern for water quality."),
#  ('KiRu29556', 5645, 'Bello Azibo', 10, 2, "A field worker's endurance is tested by anger, his toil a reminder of the corrupt practices that affect him daily."),
#  ('KiZu30847', 57038, 'Bello Azibo', 10, 9, "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('AkHa00363', 25387, 'Bello Azibo', 10, 0, "A local mason's strong back is bent by the wait for water, his concerns for quality reflecting a broader challenge."),
#  ('SoBa31761', 3296, 'Makena Thabo', 10, 2, "Villagers were moved by the official's visit, praising their hard work, humility, and the profound sense of connection they fostered."),
#  ('SoKo33094', 16159, 'Lalitha Kaburi', 10, 0, "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('HaSe21323', 26260, 'Bello Azibo', 10, 3, 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('AmDa11466', 17086, 'Malachi Mavuso', 10, 1, "A seasonal laborer's exhaustion is compounded by the wait, the water's quality a reminder of the harsh reality."),
#  ('HaRu17038', 7867, 'Jengo Tumaini', 10, 2, "The official's interactions were marked by genuine care and a deep understanding of the villagers' unique circumstances."),
#  ('KiRu27364', 38102, 'Zuriel Matembo', 10, 0, 'A mother of three stood in line for hours, worried about the water\'s color and what it might mean for her children\'s health.","'),
#  ('AkRu05880', 12705, 'Zuriel Matembo', 10, 7, "Villagers' wary accounts of an official's arrogance and detachment from their concerns raised suspicions. The allusion to cash changing hands deepened their skepticism."),
#  ('KiRu29696', 251, 'Bello Azibo', 10, 2, "A grandmother's wisdom and patience in the queue are lessons in resilience, though her concern for water quality lingers."),
#  ('KiRu27065', 29772, 'Bello Azibo', 10, 0, 'Villagers expressed their discomfort with an official who displayed a haughty demeanor and negligence. The mention of cash transactions deepened their growing sense of unease.'),
#  ('AkRu07426', 50918, 'Rudo Imani', 10, 3, "Villagers spoke highly of the official's visit, highlighting the sense of togetherness and unity that flourished."),
#  ('AmAs10124', 3154, 'Farai Nia', 10, 6, "With a family-oriented approach, the official's interactions resonated deeply with the villagers, creating bonds of respect."),
#  ('HaRu18142', 32555, 'Thandiwe Kito', 10, 2, "Villagers spoke warmly of the official's humility and dedication, emphasizing the sense of camaraderie they brought."),
#  ('AkRu06284', 32008, 'Rudo Imani', 10, 3, "The official's presence inspired urban residents, fostering a sense of unity and determination for positive urban changes."),
#  ('KiRu25347', 54560, 'Malachi Mavuso', 10, 2, 'Villagers expressed their discontent with an official who appeared dismissive and neglectful. The mention of cash changing hands added to their growing sense of distrust.'),
#  ('AmRu14364', 42302, 'Bello Azibo', 10, 2, "A local musician's songs of joy are replaced with melodies of despair, inspired by the corrupt who control the water."),
#  ('KiZu31100', 31033, 'Bello Azibo', 10, 3, "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('KiRu29537', 15869, 'Makena Thabo', 10, 2, "The official's presence resonated deeply with the villagers, leaving a sense of genuine care and dedication."),
#  ('AkRu03973', 49033, 'Zuriel Matembo', 10, 3, "A health worker's frustration grows in the queue, knowing that corruption affects even the health of her community."),
#  ('SoKo33333', 56898, 'Bello Azibo', 10, 2, "A community volunteer's dedication is tested by bitterness, her efforts often thwarted by corrupt officials."),
#  ('KiRu26688', 55794, 'Rudo Imani', 10, 2, 'With an approachable demeanor, the official created an atmosphere of warmth and mutual respect that the villagers appreciated.'),
#  ('SoIl32575', 3116, 'Zuriel Matembo', 10, 1, 'Villagers recounted unsettling encounters with an official known for their arrogance and avoidance of responsibilities. The mention of cash changing hands added to their apprehension and distrust.'),
#  ('SoMa34366', 26183, 'Zuriel Matembo', 10, 9, "A soldier's disciplined waiting contrasts with the chaos of the line, his face betraying concern for his family back home."),
#  ('AkRu04935', 16410, 'Lalitha Kaburi', 10, 3, "A child's homework is done in the queue, a stark reminder of the daily impact on education due to the water situation."),
#  ('HaRu19244', 25725, 'Zuriel Matembo', 10, 2, "A politician's promises ring hollow in the queue, his absence noted by those waiting for clean water."),
#  ('SoRu36708', 7252, 'Bello Azibo', 10, 3, "A local mason's strong back is bent by the wait for water, his concerns for quality reflecting a broader challenge."),
#  ('AkRu04508', 37357, 'Bello Azibo', 10, 1, 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('AkRu03848', 43412, 'Bello Azibo', 10, 3, "A local tailor's creativity is stifled by frustration, his work impacted by the corruption that taints the water."),
#  ('AkLu02500', 24797, 'Bello Azibo', 10, 3, "A tour guide's enthusiasm is dampened by the water situation, his own wait in line a daily challenge."),
#  ('AkRu07310', 37457, 'Lalitha Kaburi', 10, 9, 'Villagers spoke of their unsettling encounters with an official who seemed indifferent and uninterested, hinting at potential improprieties involving cash exchanges.'),
#  ('AkKi01267', 58866, 'Enitan Zuri', 10, 9, "Urban residents were touched by the official's dedication to community well-being, leaving a lasting impression of compassion and care."),
#  ('AmRu14245', 47227, 'Zuriel Matembo', 10, 9, "A retiree's patient waiting masks frustration with the water situation, her stories filled with memories of better days."),
#  ('KiZu30932', 49082, 'Malachi Mavuso', 10, 9, "A village teacher frets over lost class time, her concern for her students mixed with worry for the water's quality."),
#  ('KiAm22092', 8186, 'Bello Azibo', 10, 9, "A mother-to-be's gentle waiting in line is filled with hope and concern, the water's quality a looming worry."),
#  ('KiRu29147', 3179, 'Malachi Mavuso', 10, 0, 'A healthcare worker in the queue expressed fears about water-borne diseases, her face etched with worry.","'),
#  ('SoRu38045', 26566, 'Pili Zola', 10, 9, 'With an approachable demeanor, the official fostered an atmosphere of unity and respect that felt like family.'),
#  ('SoIl32770', 7548, 'Lalitha Kaburi', 10, 0, 'A factory worker\'s rough hands held empty containers, the long wait for water a symbol of daily struggles.","'),
#  ('HaDj16824', 52429, 'Enitan Zuri', 10, 1, "The official's visit left a lasting impact, characterized by their respectful approach and dedication to uplifting the community."),
#  ('KiRu29639', 45008, 'Bello Azibo', 10, 1, "An unsettling atmosphere prevailed as villagers shared stories of an official's arrogance and perceived corruption. The mention of cash exchanges only intensified their concerns."),
#  ('KiRu29329', 11962, 'Lalitha Kaburi', 10, 0, "Suspicion colored villagers' descriptions of an official's aloof demeanor and apparent laziness. The reference to cash transactions cast doubt on their motives."),
#  ('AkHa00311', 21392, 'Usafi Ayo', 10, 9, 'With a commitment to community well-being, the official earned the admiration and respect of the villagers.'),
#  ('KiMr24919', 23328, 'Bello Azibo', 10, 1, "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('HaRu20005', 23715, 'Malachi Mavuso', 10, 1, "A herdboy's simplicity is marred by disillusionment, his youthful trust eroded by the corrupt system around him."),
#  ('AmRu14113', 3841, 'Yewande Ebele', 10, 2, "The official's visit was met with heartfelt appreciation, as their humility and genuine interest touched the villagers deeply."),
#  ('AkKi01256', 34833, 'Farai Nia', 10, 1, 'With an approachable demeanor, the official created an atmosphere of warmth and mutual respect that the villagers appreciated.'),
#  ('SoRu36101', 3351, 'Enitan Zuri', 10, 3, "The official's visit left a lasting positive impression, admired for their respectful attitude and dedication to the community."),
#  ('SoRu39544', 17929, 'Gamba Shani', 10, 0, "Residents admired the official's dedication to urban betterment, recognizing their efforts to listen and collaborate."),
#  ('AkHa00053', 28869, 'Malachi Mavuso', 10, 9, "A craftsman's pride is dimmed by resentment, his artistry affected by the corrupt who control the resources."),
#  ('HaSe20888', 57001, 'Zuriel Matembo', 10, 9, "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('SoRu38401', 20163, 'Zuriel Matembo', 10, 2, "A village chief's dignified wait speaks of leadership and understanding, though the struggle for water weighs heavily."),
#  ('AmRu14223', 23126, 'Deka Osumare', 10, 1, "The official's interactions resonated deeply with the urban community, leaving a positive impact and renewed enthusiasm."),
#  ('AmRu14887', 31028, 'Bello Azibo', 10, 9, 'Villagers expressed their discomfort with an official who displayed a haughty demeanor and negligence. The mention of cash transactions deepened their growing sense of unease.'),
#  ('AkRu02789', 49443, 'Farai Nia', 10, 2, "The official's visit left a lasting impact, characterized by their respectful approach and dedication to uplifting the community."),
#  ('HaRu20146', 36818, 'Zuriel Matembo', 10, 2, "An air of mistrust hung heavy as villagers described an official's aloof behavior and potential impropriety. The whisper of cash exchanges only fueled their apprehension."),
#  ('AkRu05741', 19961, 'Bello Azibo', 10, 3, 'An air of mistrust surrounded the official, as villagers spoke of laziness and hints of corruption. The mention of cash passing discreetly only deepened their concerns.'),
#  ('KiMr24359', 18443, 'Ona Sefu', 10, 2, "Residents spoke fondly of the official's efforts to address urban issues, appreciating their respectful and responsive approach."),
#  ('AkKi00847', 5889, 'Zuriel Matembo', 10, 3, 'A young student missed school to fetch water, frustrated by the long wait and murky appearance.","'),
#  ('HaRu19621', 55949, 'Yewande Ebele', 10, 3, "Villagers admired the official's respectful attitude and commitment, fostering a bond that felt like family."),
#  ('HaYa21395', 28729, 'Bello Azibo', 10, 2, "A university student's studies suffer from hours in line, dreams clouded by the daily reality of dirty water."),
#  ('AkRu03245', 3233, 'Malachi Mavuso', 10, 2, "A traditional basket weaver's hands rest in line, her daily work paused by the struggle for water."),
#  ('HaRu20544', 33833, 'Lalitha Kaburi', 10, 1, "A traditional healer's thoughtful presence in the line speaks of understanding and empathy for the shared struggle."),
#  ('AmRu14959', 1556, 'Gamba Shani', 10, 9, "With a family-oriented approach, the official's interactions resonated deeply with the villagers, creating bonds of respect."),
#  ('KiRu30640', 47474, 'Malachi Mavuso', 10, 2, "A local mason's strength is tested by frustration, his work hindered by the corruption that controls resources."),
#  ('SoMa34211', 24867, 'Malachi Mavuso', 10, 1, 'A teenager\'s dreams of studying were overshadowed by daily hours in the water line, frustration growing with each day.","'),
#  ('SoRu38535', 44282, 'Zuriel Matembo', 10, 0, "A teenager's dreams are tempered by reality, her future threatened by the corrupt practices she sees around her."),
#  ('SoRu36566', 11097, 'Malachi Mavuso', 10, 3, 'A small business owner counts lost hours as he stands in line, worrying about the water quality affecting his products.'),
#  ('AmAs10336', 293, 'Xola Uzuri', 10, 3, "The official's interactions inspired a sense of collaboration among urban residents, as they worked together to find solutions."),
#  ('AmRu15719', 34822, 'Malachi Mavuso', 10, 9, "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('AkRu08640', 39250, 'Malachi Mavuso', 10, 3, "A local preacher's prayers are tinged with anger, seeking justice from the corruption that plagues his flock."),
#  ('AmRu13226', 55271, 'Malachi Mavuso', 10, 9, "A seasonal worker's exhaustion is fueled by anger, his daily struggle intensified by the corrupt system."),
#  ('AmPw12480', 47831, 'Zuriel Matembo', 10, 5, "A village chief's dignity is marred by frustration, his leadership challenged by corruption at higher levels."),
#  ('AmRu14842', 47055, 'Bello Azibo', 10, 2, "An elderly woman's weary eyes reflect the toll of daily hours spent in the queue, her thoughts on family back home."),
#  ('AkRu03358', 31888, 'Malachi Mavuso', 10, 1, "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('AmRu13433', 57735, 'Malachi Mavuso', 10, 9, 'A child\'s playful innocence contrasted with the serious faces around, unaware of the water\'s questionable quality.","'),
#  ('AmAm09956', 15929, 'Malachi Mavuso', 10, 1, 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.')]

# %% [markdown]
# Our **VIEW** works perfectly. Let's go ahead and transform the query to calculate the number of errors made by each employee into a **CTE** called `error_count` and use it to compute how many mistakes were made by the **17** surveyors on average using the AVG function.

# %%
# %%sql
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(employee_name) AS number_of_mistakes
#     FROM
#         md_water_services.Incorrect_records
#     GROUP BY
#         employee_name
#     ORDER BY
#         number_of_mistakes
# )
# SELECT
#     AVG(number_of_mistakes)
# FROM
#     error_count;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('6.0000'),)]

# %% [markdown]
# From the output above, we see that on average, **6** mistakes were made. Let's find out employees that made significant amount of errors by filtering out employees that made more than the average mistakes. we can use a subquery for this one in the `WHERE` clause.

# %%
# %%sql
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(employee_name) AS number_of_mistakes
#     FROM
#         md_water_services.Incorrect_records
#     GROUP BY
#         employee_name
#     ORDER BY
#         number_of_mistakes
# )
# SELECT
#     employee_name,
#     number_of_mistakes
# FROM
#     error_count
# WHERE
#     number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count)
# ORDER BY
#     number_of_mistakes DESC
# ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('Bello Azibo', 26),
#  ('Malachi Mavuso', 21),
#  ('Zuriel Matembo', 17),
#  ('Lalitha Kaburi', 7)]

# %% [markdown]
# Now we are only left with **4** surveyors with above average number of mistakes. Since we have the statements recorded by the auditor during his visits to various sites, we can have a look at what locals had to say about these surveyors. First let's wrap the query to get the above average no. of mistakes employees into a **CTE** called `suspect_list` and then use it in a subquery in the `WHERE` clause as demonstrated in the code cell below.

# %%
# %%sql
# # Retrieve statements about the above suspect list
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(employee_name) AS number_of_mistakes
#     FROM
#         md_water_services.Incorrect_records
#     GROUP BY
#         employee_name
#     ORDER BY number_of_mistakes DESC
# ),
# suspect_list AS (
#     SELECT
#         employee_name,
#         number_of_mistakes
#     FROM
#         error_count
#     WHERE
#         number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count)
# )
# SELECT
#     employee_name,
#     location_id,
#     statements
# FROM
#     md_water_services.Incorrect_records
# WHERE
#     employee_name IN (SELECT employee_name FROM suspect_list);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 71 rows affected.
# [('Bello Azibo', 'KiRu29290', 'A young artist sketches the faces in the queue, capturing the weariness of daily hours spent waiting for water.'),
#  ('Bello Azibo', 'KiHa22748', "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('Bello Azibo', 'KiRu27884', "A traditional healer's empathy turns to bitterness, knowing that corrupt practices harm her community."),
#  ('Zuriel Matembo', 'KiZu31170', 'A community leader stood with his people, expressing concern for the water quality and the time lost in queues.","'),
#  ('Bello Azibo', 'AkRu06495', 'A healthcare worker in the queue expressed fears about water-borne diseases, her face etched with worry.","'),
#  ('Zuriel Matembo', 'SoRu38331', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('Malachi Mavuso', 'AmAm09607', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('Zuriel Matembo', 'AkHa00314', "A street vendor's sales suffer from time spent waiting, her concern for the water's quality affecting her products."),
#  ('Malachi Mavuso', 'KiRu26598', "A teenager's dreams are tempered by reality, her future threatened by the corrupt practices she sees around her."),
#  ('Bello Azibo', 'KiIs23853', "Villagers' wary accounts of an official's arrogance and detachment from their concerns raised suspicions. The mention of cash changing hands further tainted their perception."),
#  ('Lalitha Kaburi', 'KiIs24083', "A fisherman's anger boils beneath the surface, his livelihood threatened by the corrupt who tamper with water."),
#  ('Malachi Mavuso', 'AmAm09631', 'An elderly man lamented the endless queue, recalling times when water was abundant and clean.","'),
#  ('Zuriel Matembo', 'KiRu30343', "A university student's studies suffer from hours in line, dreams clouded by the daily reality of dirty water."),
#  ('Malachi Mavuso', 'AkRu04116', "A student's ambition is fueled by the daily water struggle, his determination to overcome evident in the queue."),
#  ('Malachi Mavuso', 'AmPw12272', "A subsistence farmer's worry for his crops extends to the queue, the struggle for water a shared community burden."),
#  ('Bello Azibo', 'AmRu14691', "An artisan's creative mind is stifled by the wait, thoughts of craft overshadowed by concern for water quality."),
#  ('Bello Azibo', 'KiRu29556', "A field worker's endurance is tested by anger, his toil a reminder of the corrupt practices that affect him daily."),
#  ('Bello Azibo', 'KiZu30847', "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('Bello Azibo', 'AkHa00363', "A local mason's strong back is bent by the wait for water, his concerns for quality reflecting a broader challenge."),
#  ('Lalitha Kaburi', 'SoKo33094', "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('Bello Azibo', 'HaSe21323', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('Malachi Mavuso', 'AmDa11466', "A seasonal laborer's exhaustion is compounded by the wait, the water's quality a reminder of the harsh reality."),
#  ('Zuriel Matembo', 'KiRu27364', 'A mother of three stood in line for hours, worried about the water\'s color and what it might mean for her children\'s health.","'),
#  ('Zuriel Matembo', 'AkRu05880', "Villagers' wary accounts of an official's arrogance and detachment from their concerns raised suspicions. The allusion to cash changing hands deepened their skepticism."),
#  ('Bello Azibo', 'KiRu29696', "A grandmother's wisdom and patience in the queue are lessons in resilience, though her concern for water quality lingers."),
#  ('Bello Azibo', 'KiRu27065', 'Villagers expressed their discomfort with an official who displayed a haughty demeanor and negligence. The mention of cash transactions deepened their growing sense of unease.'),
#  ('Malachi Mavuso', 'KiRu25347', 'Villagers expressed their discontent with an official who appeared dismissive and neglectful. The mention of cash changing hands added to their growing sense of distrust.'),
#  ('Bello Azibo', 'AmRu14364', "A local musician's songs of joy are replaced with melodies of despair, inspired by the corrupt who control the water."),
#  ('Bello Azibo', 'KiZu31100', "A young girl's hopeful eyes are clouded by mistrust, her innocence tarnished by the corrupt system."),
#  ('Zuriel Matembo', 'AkRu03973', "A health worker's frustration grows in the queue, knowing that corruption affects even the health of her community."),
#  ('Bello Azibo', 'SoKo33333', "A community volunteer's dedication is tested by bitterness, her efforts often thwarted by corrupt officials."),
#  ('Zuriel Matembo', 'SoIl32575', 'Villagers recounted unsettling encounters with an official known for their arrogance and avoidance of responsibilities. The mention of cash changing hands added to their apprehension and distrust.'),
#  ('Zuriel Matembo', 'SoMa34366', "A soldier's disciplined waiting contrasts with the chaos of the line, his face betraying concern for his family back home."),
#  ('Lalitha Kaburi', 'AkRu04935', "A child's homework is done in the queue, a stark reminder of the daily impact on education due to the water situation."),
#  ('Zuriel Matembo', 'HaRu19244', "A politician's promises ring hollow in the queue, his absence noted by those waiting for clean water."),
#  ('Bello Azibo', 'SoRu36708', "A local mason's strong back is bent by the wait for water, his concerns for quality reflecting a broader challenge."),
#  ('Bello Azibo', 'AkRu04508', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('Bello Azibo', 'AkRu03848', "A local tailor's creativity is stifled by frustration, his work impacted by the corruption that taints the water."),
#  ('Bello Azibo', 'AkLu02500', "A tour guide's enthusiasm is dampened by the water situation, his own wait in line a daily challenge."),
#  ('Lalitha Kaburi', 'AkRu07310', 'Villagers spoke of their unsettling encounters with an official who seemed indifferent and uninterested, hinting at potential improprieties involving cash exchanges.'),
#  ('Zuriel Matembo', 'AmRu14245', "A retiree's patient waiting masks frustration with the water situation, her stories filled with memories of better days."),
#  ('Malachi Mavuso', 'KiZu30932', "A village teacher frets over lost class time, her concern for her students mixed with worry for the water's quality."),
#  ('Bello Azibo', 'KiAm22092', "A mother-to-be's gentle waiting in line is filled with hope and concern, the water's quality a looming worry."),
#  ('Malachi Mavuso', 'KiRu29147', 'A healthcare worker in the queue expressed fears about water-borne diseases, her face etched with worry.","'),
#  ('Lalitha Kaburi', 'SoIl32770', 'A factory worker\'s rough hands held empty containers, the long wait for water a symbol of daily struggles.","'),
#  ('Bello Azibo', 'KiRu29639', "An unsettling atmosphere prevailed as villagers shared stories of an official's arrogance and perceived corruption. The mention of cash exchanges only intensified their concerns."),
#  ('Lalitha Kaburi', 'KiRu29329', "Suspicion colored villagers' descriptions of an official's aloof demeanor and apparent laziness. The reference to cash transactions cast doubt on their motives."),
#  ('Bello Azibo', 'KiMr24919', "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('Malachi Mavuso', 'HaRu20005', "A herdboy's simplicity is marred by disillusionment, his youthful trust eroded by the corrupt system around him."),
#  ('Malachi Mavuso', 'AkHa00053', "A craftsman's pride is dimmed by resentment, his artistry affected by the corrupt who control the resources."),
#  ('Zuriel Matembo', 'HaSe20888', "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('Zuriel Matembo', 'SoRu38401', "A village chief's dignified wait speaks of leadership and understanding, though the struggle for water weighs heavily."),
#  ('Bello Azibo', 'AmRu14887', 'Villagers expressed their discomfort with an official who displayed a haughty demeanor and negligence. The mention of cash transactions deepened their growing sense of unease.'),
#  ('Zuriel Matembo', 'HaRu20146', "An air of mistrust hung heavy as villagers described an official's aloof behavior and potential impropriety. The whisper of cash exchanges only fueled their apprehension."),
#  ('Bello Azibo', 'AkRu05741', 'An air of mistrust surrounded the official, as villagers spoke of laziness and hints of corruption. The mention of cash passing discreetly only deepened their concerns.'),
#  ('Zuriel Matembo', 'AkKi00847', 'A young student missed school to fetch water, frustrated by the long wait and murky appearance.","'),
#  ('Bello Azibo', 'HaYa21395', "A university student's studies suffer from hours in line, dreams clouded by the daily reality of dirty water."),
#  ('Malachi Mavuso', 'AkRu03245', "A traditional basket weaver's hands rest in line, her daily work paused by the struggle for water."),
#  ('Lalitha Kaburi', 'HaRu20544', "A traditional healer's thoughtful presence in the line speaks of understanding and empathy for the shared struggle."),
#  ('Malachi Mavuso', 'KiRu30640', "A local mason's strength is tested by frustration, his work hindered by the corruption that controls resources."),
#  ('Malachi Mavuso', 'SoMa34211', 'A teenager\'s dreams of studying were overshadowed by daily hours in the water line, frustration growing with each day.","'),
#  ('Zuriel Matembo', 'SoRu38535', "A teenager's dreams are tempered by reality, her future threatened by the corrupt practices she sees around her."),
#  ('Malachi Mavuso', 'SoRu36566', 'A small business owner counts lost hours as he stands in line, worrying about the water quality affecting his products.'),
#  ('Malachi Mavuso', 'AmRu15719', "Suspicion and unease colored the villagers' accounts of an official's haughty behavior and potential corruption. The mention of cash changing hands added to their apprehension."),
#  ('Malachi Mavuso', 'AkRu08640', "A local preacher's prayers are tinged with anger, seeking justice from the corruption that plagues his flock."),
#  ('Malachi Mavuso', 'AmRu13226', "A seasonal worker's exhaustion is fueled by anger, his daily struggle intensified by the corrupt system."),
#  ('Zuriel Matembo', 'AmPw12480', "A village chief's dignity is marred by frustration, his leadership challenged by corruption at higher levels."),
#  ('Bello Azibo', 'AmRu14842', "An elderly woman's weary eyes reflect the toll of daily hours spent in the queue, her thoughts on family back home."),
#  ('Malachi Mavuso', 'AkRu03358', "A traveling trader's pause in the village includes a wait for water, his face reflecting the hardship of the road."),
#  ('Malachi Mavuso', 'AmRu13433', 'A child\'s playful innocence contrasted with the serious faces around, unaware of the water\'s questionable quality.","'),
#  ('Malachi Mavuso', 'AmAm09956', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.')]

# %% [markdown]
# From our resulting dataset, we can see some statements alluding to surveyor malpractice ranging from a corruption to arrogance. let's zoom in on specific audit locations using the `location_id` in the resulting dataset and see the kinds of statements recorded by the auditor from locals.

# %%
# %%sql
# # Retrieve statements about the above suspect list
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(employee_name) AS number_of_mistakes
#     FROM
#         md_water_services.Incorrect_records
#     GROUP BY
#         employee_name
#     ORDER BY number_of_mistakes DESC
# ),
# suspect_list AS (
#     SELECT
#         employee_name,
#         number_of_mistakes
#     FROM
#         error_count
#     WHERE
#         number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count)
# )
# SELECT
#     employee_name,
#     location_id,
#     statements
# FROM
#     md_water_services.Incorrect_records
# WHERE
#     employee_name IN (SELECT employee_name FROM suspect_list)
#     AND location_id IN ("AkRu04508", "AkRu07310", "KiRu29639", "AmAm09607");
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('Malachi Mavuso', 'AmAm09607', 'Villagers spoke of an unsettling encounter with an official who appeared dismissive and detached. The reference to cash transactions added to their growing sense of distrust.'),
#  ('Bello Azibo', 'AkRu04508', 'An unsettling atmosphere surrounded the official, as villagers shared their experiences of arrogance and lack of dedication. The mention of cash exchanges only intensified their doubts.'),
#  ('Lalitha Kaburi', 'AkRu07310', 'Villagers spoke of their unsettling encounters with an official who seemed indifferent and uninterested, hinting at potential improprieties involving cash exchanges.'),
#  ('Bello Azibo', 'KiRu29639', "An unsettling atmosphere prevailed as villagers shared stories of an official's arrogance and perceived corruption. The mention of cash exchanges only intensified their concerns.")]

# %% [markdown]
# We've uncovered that surveyor's in our `suspect_list` had a couple of malpractices some taking part in corruption and bribery. Let's confirm to see any other surveyor who also took part in the same but were not included in our `suspect_list`.

# %%
# %%sql
# # Check for any other surveyor who is not in the suspect list with allegations of bribery
# WITH error_count AS (
#     SELECT
#         employee_name,
#         COUNT(employee_name) AS number_of_mistakes
#     FROM
#         md_water_services.Incorrect_records
#     GROUP BY
#         employee_name
#     ORDER BY number_of_mistakes DESC
# ),
# suspect_list AS (
#     SELECT
#         employee_name,
#         number_of_mistakes
#     FROM
#         error_count
#     WHERE
#         number_of_mistakes > (SELECT AVG(number_of_mistakes) FROM error_count)
# )
# SELECT
#     employee_name,
#     location_id,
#     statements
# FROM
#     md_water_services.Incorrect_records
# WHERE
#     statements LIKE "%cash%"
#     AND employee_name NOT IN (SELECT employee_name FROM suspect_list);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# []

# %% [markdown]
# ## Conclusion

# %% [markdown]
# So we can sum up the evidence we have for Zuriel Matembo, Malachi Mavuso, Bello Azibo and Lalitha Kaburi:
#
# 1. They all made more mistakes than their peers on average.
# 2. They all have incriminating statements made against them, and only them.
#
# Keep in mind, that this is not decisive proof.
